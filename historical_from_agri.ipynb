# %%
from google.colab import drive
drive.mount('/content/drive')
ROOT = './'
ROOT='/content/drive/MyDrive/Colab Notebooks/historical_weather'
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import requests
from dateutil.parser import parse
import json
from datetime import datetime, timedelta
import os

# %%
def agr_get_sta_list(area_id=0, level_id=0):
    my_headers = {    
        "accept": "application/json, text/javascript, */*; q=0.01",
        "accept-language": "ja-JP,ja;q=0.9,zh-TW;q=0.8,zh;q=0.7,en-US;q=0.6,en;q=0.5",
        "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
        "sec-ch-ua": "\"Chromium\";v=\"92\", \" Not A;Brand\";v=\"99\", \"Google Chrome\";v=\"92\"",
        "sec-ch-ua-mobile": "?0",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "x-requested-with": "XMLHttpRequest", #required
    }
    URI = 'https://agr.cwb.gov.tw/NAGR/history/station_day/get_station_name'
    area = ['', '北', '中', '南', '東'][area_id]
    level = ['自動站', '新農業站'][level_id]
    r1 = requests.post(URI, data={'area':area, 'level':level}, headers = my_headers)
    sta_dict = json.loads(r1.text)
    df = pd.DataFrame(sta_dict)
    extract_df = df[['ID', 'Cname', 'Altitude', 'Latitude_WGS84', 'Longitude_WGS84', 'Address', 'StnBeginTime', 'stnendtime', 'stationlist_auto']]
    extract_df.columns=['站號', '站名', '海拔高度(m)', '緯度', '經度', '地址', '資料起始日期', '撤站日期', '備註']
    return extract_df
def load_weather_station_list(include_suspended = False, include_agr_sta = True):
    #load from CWB
    raw = pd.read_html('https://e-service.cwb.gov.tw/wdps/obs/state.htm')
    weather_station_list = raw[0]
    if include_suspended:
        weather_station_list =  weather_station_list.append(raw[1])
    #load from agri
    if include_agr_sta:
        weather_station_list = weather_station_list.append(agr_get_sta_list(level_id=1), ignore_index = True)
    return weather_station_list

# %%
#Fetch From https://agr.cwb.gov.tw/NAGR/history/station_day
my_headers = {    
    "accept": "application/json, text/javascript, */*; q=0.01",
    "accept-language": "ja-JP,ja;q=0.9,zh-TW;q=0.8,zh;q=0.7,en-US;q=0.6,en;q=0.5",
    "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
    "sec-ch-ua": "\"Chromium\";v=\"92\", \" Not A;Brand\";v=\"99\", \"Google Chrome\";v=\"92\"",
    "sec-ch-ua-mobile": "?0",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "x-requested-with": "XMLHttpRequest", #required
}

def agr_get_hour_data (station = '466910', start_time = '2021-08-24', end_time = '2021-08-24', items=['PrecpHour']):
    get_hour = "https://agr.cwb.gov.tw/NAGR/history/station_hour/get_station_hour"
    #資料有可能存在「自動站」的資料庫
    #資料庫對自動站及農業站的日期處理行為不同
    start_time_dt = parse(start_time)
    end_time_dt = parse(end_time)
    r1 = requests.post(get_hour, data = {'station' : station, 'start_time': start_time_dt.strftime('%Y%m%d'), 'end_time': end_time_dt.strftime('%Y%m%d'), 'items[]': items, 'level': ''}, headers = my_headers)
    r2 = requests.post(get_hour, data = {'station' : station, 'start_time': start_time_dt.strftime('%Y%m%d'), 'end_time': end_time_dt.strftime('%Y%m%d'), 'items[]': items, 'level': '自動站'}, headers = my_headers)
    #return r1.text,r2.text
    #Try parsing return data
    try:
        r1_parsed = json.loads(r1.text)['result']
    except Exception as e:
        r1_parsed=[]
        print('r1 parse error: ',e, r1.text)
        
    try:
        r2_parsed = json.loads(r2.text)['result']
    except Exception as e:
        r2_parsed=[]
        print('r2 parse error: ',e, r2.text)

    
    #only one of r1 and r2 will contain required data
    if r1_parsed != []:
        #print (station, "為農業站")
        return r1_parsed
    if r2_parsed != []:
        #print (station, "為自動站")
        return r2_parsed
    return []


def agr_get_items (station = '466910'): #check available fields
    get_items_URI = "https://agr.cwb.gov.tw/NAGR/history/station_day/get_items"
    r = requests.post(get_items_URI, data = {'station': station},  headers= my_headers)
    try:
        return json.loads(r.text)['columns']
    except:
        return r.text
    
def agr_parsing (f):
    try:
        rt = list(f.values())[0]
        rt = float(rt)
        if rt < -90:
            return -999
        return rt
    except Exception as e:
        return -999
    
    
def agr_fetch (station_num=467080, date='2021-08-16'):
    output_columns = {
        'StaNO': '站號',
        'ObsTime': '觀測時間(hour)',
        'StnPres': '測站氣壓(hPa)',
        'SeaPres': '海平面氣壓(hPa)',
        'Tx': '氣溫(℃)',
        'Td': '露點溫度(℃)',
        'RH': '相對溼度(%)',
        'WS': '風速(m/s)',
        'WD': '風向(360degree)',
        'WSGust': '最大陣風(m/s)',
        'WDGust': '最大陣風風向(360degree)',
        'Precp': '降水量(mm)',
        'PrecpHr': '降水時數(hr)',
        'SunShine': '日照時數(hr)',
        'GloblRad': '全天空日射量(MJ/㎡)',
        'Visb': '能見度(km)',
        'UVI': '紫外線指數',
        'Cloud':'總雲量(0~10)'}
    #initialize the dataFrame
    station='C0Z200'
    df = pd.DataFrame(columns = output_columns.values())
    #如果items裡面放了他資料庫沒有的東西，會發生錯誤。所以得自己先確認交集
    sta_item = set(output_columns.keys()).intersection(agr_get_items(station_num))
    d = agr_get_hour_data(station=station_num,start_time=date, end_time=date, items=sta_item)
    df['觀測時間(hour)'] = pd.date_range(date+' 01:00:00', periods=24, freq='1h')
    df['站號'] = station_num
    df.set_index('觀測時間(hour)', inplace=True)
    #if no valid data
    if (d==[]):
        return pd.DataFrame()
    for single_factor in d:
        for rec in single_factor:
            #{'StnPres': '924.4', 'ObsTime': '2020-08-15 02:00:00'}
            ObsTime = parse(rec['ObsTime'])
            #in case of 8/16 23:59:00
            if ObsTime.strftime('%H%M')=='2359':
                ObsTime += timedelta(minutes=1)
            del rec['ObsTime']
            #After deleting ObsTime, the last key left is the observation data
            col_code = list(rec)[0]
            col_name = output_columns[col_code]
            #fill the data into the table
            df.loc[ObsTime,col_name] = rec[col_code]

    df.fillna(-999, inplace=True)
    df.reset_index(inplace=True)
    #dt need to be converted to str before enter MySQL
    df['觀測時間(hour)'] = df['觀測時間(hour)'].dt.strftime('%Y-%m-%d %H:%i:%s')
    
    return df

def agr_fetch_year_full (station_num=467080, year='2021', save_path = ''):
    sta_item = agr_get_items(station_num)
    df = pd.DataFrame()
    for month in range(1,13):
        start_time = '{}/{}/{}'.format(year,month,'1')
        if month == 12:
            end_time = '{}/{}/{}'.format(year,month,'31')
        else:
            end_time = (parse('{}/{}/{}'.format(year,month + 1,'1')) - timedelta(days = 1)).strftime('%Y/%m/%d')
        data_list = agr_get_hour_data(station=station_num,start_time=start_time, end_time=end_time, items=sta_item)
        df = df.append(agr_factor_to_df(data_list))     
    if save_path != '':
        df.to_csv(save_path, encoding = 'utf-8-sig')
    print(station_num, year,'downloaded')
    return df
    
def add_1min_to_2359 (d):
    if d.strftime('%H%M')=='2359':
        d += timedelta(minutes=1)
    return d

def agr_factor_to_df (d):
    df = pd.DataFrame()
    for r in d:
       
        keys = list(r[0])
        keys.remove('ObsTime')
        #There will be two keys in the data, one is the observation time, and the other is the query data
        factor_key = keys[0]
        data = [row[factor_key] for row in r]
        ObsTime = [parse(row['ObsTime']) for row in r]
        ObsTime = list(map(add_1min_to_2359 , ObsTime))
        df_temp = pd.DataFrame(index = ObsTime)
        #df_temp.index = ObsTime
        df_temp[factor_key] = data
        if df.empty:
            df = df_temp.copy()
        else: 
            df = pd.merge(df, df_temp, left_index=True, right_index=True, how='outer')
    return df

# %%
sta_list = load_weather_station_list(include_suspended = True)

# %%
import concurrent.futures

# %%
for index, row in sta_list[1:].iterrows():
    sta_info = {}
    sta_info ['sta_no'] = row[0]
    sta_info ['sta_name'] = row[1]
    sta_info ['start'] = parse(row[7])
    try:
        sta_info ['end'] = parse(row[8])
    except Exception as e:
        sta_info ['end'] = datetime.today()
    DIR_PATH = os.path.join(ROOT,'data',sta_info ['sta_no'])
    os.makedirs(DIR_PATH, exist_ok=True)
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures=[]
        for year in range(sta_info['start'].year, sta_info['end'].year +1):
            CSV_PATH = os.path.join(DIR_PATH,sta_info['sta_no']+'_'+str(year)+'.csv')
            try:
                #Check if file is already downloded
                if os.path.isfile(CSV_PATH) == False:
                    print ('Try downloading',index, sta_info['sta_no'], year)
                    future = executor.submit(
                                                agr_fetch_year_full, sta_info['sta_no'], 
                                                year, 
                                                CSV_PATH
                                            )
                    futures.append(future)
                else:
                    print(CSV_PATH, 'already downloaded, skipped')
            except Exception as e:
                print(e)
        #wait job to be finished
        try:
            for future in futures:
                future.result(timeout=300)
        except concurrent.futures.TimeoutError:
            print('Timeout error', future)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC40/C0AC40_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC40/C0AC40_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC40/C0AC40_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC40/C0AC40_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC60/C0AC60_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC60/C0AC60_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC60/C0AC60_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC60/C0AC60_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC60/C0AC60_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC60/C0AC60_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC60/C0AC60_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC60/C0AC60_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC60/C0AC60_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC60/C0AC60_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC60/C0AC60_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC60/C0AC60_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC60/C0AC60_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC60/C0AC60_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC70/C0AC70_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC70/C0AC70_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC70/C0AC70_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC70/C0AC70_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC70/C0AC70_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC70/C0AC70_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC70/C0AC70_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC70/C0AC70_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC70/C0AC70_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC70/C0AC70_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC70/C0AC70_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC70/C0AC70_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC70/C0AC70_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC70/C0AC70_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC80/C0AC80_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC80/C0AC80_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC80/C0AC80_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC80/C0AC80_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC80/C0AC80_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC80/C0AC80_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC80/C0AC80_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC80/C0AC80_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC80/C0AC80_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC80/C0AC80_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC80/C0AC80_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC80/C0AC80_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC80/C0AC80_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AC80/C0AC80_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0ACA0/C0ACA0_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0ACA0/C0ACA0_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0ACA0/C0ACA0_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0ACA0/C0ACA0_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0ACA0/C0ACA0_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0ACA0/C0ACA0_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0ACA0/C0ACA0_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0ACA0/C0ACA0_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0ACA0/C0ACA0_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0ACA0/C0ACA0_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0ACA0/C0ACA0_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0ACA0/C0ACA0_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0ACA0/C0ACA0_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0ACA0/C0ACA0_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD00/C0AD00_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD00/C0AD00_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD00/C0AD00_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD00/C0AD00_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD00/C0AD00_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD00/C0AD00_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD00/C0AD00_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD00/C0AD00_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD00/C0AD00_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD00/C0AD00_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD00/C0AD00_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD00/C0AD00_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD00/C0AD00_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD00/C0AD00_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD10/C0AD10_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD10/C0AD10_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD10/C0AD10_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD10/C0AD10_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD10/C0AD10_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD10/C0AD10_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD10/C0AD10_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD10/C0AD10_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD10/C0AD10_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD10/C0AD10_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD10/C0AD10_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD10/C0AD10_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD10/C0AD10_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD10/C0AD10_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD30/C0AD30_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD30/C0AD30_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD30/C0AD30_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD30/C0AD30_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD30/C0AD30_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD30/C0AD30_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD30/C0AD30_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD30/C0AD30_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD30/C0AD30_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD30/C0AD30_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD30/C0AD30_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD30/C0AD30_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD30/C0AD30_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD30/C0AD30_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD40/C0AD40_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD40/C0AD40_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD40/C0AD40_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD40/C0AD40_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD40/C0AD40_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD40/C0AD40_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD40/C0AD40_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD40/C0AD40_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD40/C0AD40_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD40/C0AD40_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD40/C0AD40_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD40/C0AD40_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD40/C0AD40_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD40/C0AD40_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD50/C0AD50_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD50/C0AD50_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD50/C0AD50_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD50/C0AD50_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD50/C0AD50_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD50/C0AD50_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD50/C0AD50_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD50/C0AD50_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD50/C0AD50_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD50/C0AD50_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD50/C0AD50_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD50/C0AD50_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD50/C0AD50_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AD50/C0AD50_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AG80/C0AG80_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AG80/C0AG80_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH00/C0AH00_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH00/C0AH00_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH00/C0AH00_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH00/C0AH00_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH00/C0AH00_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH00/C0AH00_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH00/C0AH00_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH00/C0AH00_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH00/C0AH00_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH00/C0AH00_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH00/C0AH00_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH00/C0AH00_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH10/C0AH10_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH10/C0AH10_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH10/C0AH10_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH10/C0AH10_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH10/C0AH10_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH10/C0AH10_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH10/C0AH10_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH10/C0AH10_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH10/C0AH10_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH30/C0AH30_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH30/C0AH30_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH30/C0AH30_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH30/C0AH30_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH30/C0AH30_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH30/C0AH30_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH30/C0AH30_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH40/C0AH40_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH40/C0AH40_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH40/C0AH40_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH40/C0AH40_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH40/C0AH40_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH40/C0AH40_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH40/C0AH40_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH50/C0AH50_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH50/C0AH50_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH50/C0AH50_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH50/C0AH50_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH50/C0AH50_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH50/C0AH50_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH70/C0AH70_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH70/C0AH70_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH70/C0AH70_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH70/C0AH70_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH70/C0AH70_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH70/C0AH70_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH80/C0AH80_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH80/C0AH80_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH80/C0AH80_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH80/C0AH80_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH80/C0AH80_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH80/C0AH80_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH90/C0AH90_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH90/C0AH90_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH90/C0AH90_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH90/C0AH90_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AH90/C0AH90_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI00/C0AI00_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI00/C0AI00_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI00/C0AI00_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI00/C0AI00_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI00/C0AI00_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI10/C0AI10_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI10/C0AI10_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI10/C0AI10_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI10/C0AI10_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI10/C0AI10_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI20/C0AI20_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI20/C0AI20_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI20/C0AI20_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI20/C0AI20_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI20/C0AI20_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI30/C0AI30_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI30/C0AI30_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI30/C0AI30_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI30/C0AI30_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI40/C0AI40_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI40/C0AI40_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI40/C0AI40_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0AI40/C0AI40_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0B010/C0B010_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0B010/C0B010_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0B010/C0B010_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0B010/C0B010_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0B010/C0B010_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0B020/C0B020_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0B020/C0B020_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0B020/C0B020_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0B020/C0B020_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0B020/C0B020_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C460/C0C460_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C480/C0C480_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C490/C0C490_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C490/C0C490_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C490/C0C490_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C490/C0C490_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C490/C0C490_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C490/C0C490_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C490/C0C490_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C490/C0C490_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C490/C0C490_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C490/C0C490_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C490/C0C490_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C490/C0C490_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C540/C0C540_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C590/C0C590_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C620/C0C620_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C620/C0C620_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C620/C0C620_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C620/C0C620_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C620/C0C620_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C620/C0C620_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C620/C0C620_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C620/C0C620_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C620/C0C620_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C620/C0C620_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C620/C0C620_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C620/C0C620_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C630/C0C630_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C650/C0C650_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C660/C0C660_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C660/C0C660_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C660/C0C660_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C660/C0C660_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C660/C0C660_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C660/C0C660_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C660/C0C660_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C660/C0C660_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C660/C0C660_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C660/C0C660_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C670/C0C670_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C670/C0C670_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C670/C0C670_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C670/C0C670_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C670/C0C670_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C670/C0C670_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C670/C0C670_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C670/C0C670_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C670/C0C670_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C680/C0C680_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C680/C0C680_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C680/C0C680_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C680/C0C680_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C680/C0C680_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C680/C0C680_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C700/C0C700_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C700/C0C700_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C700/C0C700_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C700/C0C700_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C700/C0C700_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C700/C0C700_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C710/C0C710_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C710/C0C710_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C710/C0C710_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C710/C0C710_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0C710/C0C710_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_1987.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_1988.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_1989.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_1990.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_1991.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_1992.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_1993.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_1994.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_1995.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_1996.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_1997.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_1998.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_1999.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2000.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2001.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2002.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2003.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2004.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2005.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2006.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D360/C0D360_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D390/C0D390_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D390/C0D390_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D390/C0D390_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D390/C0D390_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D390/C0D390_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D390/C0D390_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0D390/C0D390_2014.csv already downloaded, skipped
# ...
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A630/C1A630_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A630/C1A630_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A630/C1A630_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A630/C1A630_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A630/C1A630_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A630/C1A630_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A630/C1A630_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A630/C1A630_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A630/C1A630_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A630/C1A630_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A630/C1A630_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A630/C1A630_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A750/C1A750_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A750/C1A750_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A760/C1A760_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A760/C1A760_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2000.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2001.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2002.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2003.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2004.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2005.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2006.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1A9N0/C1A9N0_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_1992.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_1993.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_1994.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_1995.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_1996.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_1997.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_1998.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_1999.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2000.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2001.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2002.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2003.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2004.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2005.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2006.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2014.csv already downloaded, skipped
# Try downloading 472 C1AC50 2015
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C1AC50/C1AC50_2022.csv already downloaded, skipped
# C1AC50 2015 downloaded
# Try downloading 473 C1AI50 2021
# Try downloading 473 C1AI50 2022
# C1AI50 2022 downloaded
# C1AI50 2021 downloaded
# Try downloading 474 C1AI60 2021
# Try downloading 474 C1AI60 2022
# C1AI60 2022 downloaded
# C1AI60 2021 downloaded
# Try downloading 475 C1C510 1987
# Try downloading 475 C1C510 1988
# Try downloading 475 C1C510 1989
# Try downloading 475 C1C510 1990
# Try downloading 475 C1C510 1991
# Try downloading 475 C1C510 1992
# Try downloading 475 C1C510 1993
# Try downloading 475 C1C510 1994
# Try downloading 475 C1C510 1995
# Try downloading 475 C1C510 1996
# Try downloading 475 C1C510 1997
# Try downloading 475 C1C510 1998
# Try downloading 475 C1C510 1999
# Try downloading 475 C1C510 2000
# Try downloading 475 C1C510 2001
# Try downloading 475 C1C510 2002
# Try downloading 475 C1C510 2003
# Try downloading 475 C1C510 2004
# Try downloading 475 C1C510 2005
# Try downloading 475 C1C510 2006
# Try downloading 475 C1C510 2007
# Try downloading 475 C1C510 2008
# Try downloading 475 C1C510 2009
# Try downloading 475 C1C510 2010
# Try downloading 475 C1C510 2011
# Try downloading 475 C1C510 2012
# Try downloading 475 C1C510 2013
# Try downloading 475 C1C510 2014
# Try downloading 475 C1C510 2015
# Try downloading 475 C1C510 2016
# Try downloading 475 C1C510 2017
# Try downloading 475 C1C510 2018
# Try downloading 475 C1C510 2019
# Try downloading 475 C1C510 2020
# Try downloading 475 C1C510 2021
# Try downloading 475 C1C510 2022
# C1C510 1987 downloaded
# C1C510 1996 downloaded
# C1C510 1988 downloaded
# C1C510 1989 downloaded
# C1C510 1993 downloaded
# C1C510 1995 downloaded
# C1C510 1994 downloaded
# C1C510 1990 downloaded
# C1C510 1992 downloaded
# C1C510 1991 downloaded
# C1C510 1997 downloaded
# C1C510 2001 downloaded
# C1C510 2000 downloaded
# C1C510 1998 downloaded
# C1C510 2002 downloaded
# C1C510 1999 downloaded
# C1C510 2004 downloaded
# C1C510 2003 downloaded
# C1C510 2005 downloaded
# C1C510 2006 downloaded
# C1C510 2007 downloaded
# C1C510 2008 downloaded
# C1C510 2009 downloaded
# C1C510 2010 downloaded
# C1C510 2011 downloaded
# C1C510 2013 downloaded
# C1C510 2012 downloaded
# C1C510 2015 downloaded
# C1C510 2014 downloaded
# C1C510 2016 downloaded
# C1C510 2022 downloaded
# C1C510 2017 downloaded
# C1C510 2018 downloaded
# C1C510 2019 downloaded
# C1C510 2020 downloaded
# C1C510 2021 downloaded
# Try downloading 476 C1D380 1987
# Try downloading 476 C1D380 1988
# Try downloading 476 C1D380 1989
# Try downloading 476 C1D380 1990
# Try downloading 476 C1D380 1991
# Try downloading 476 C1D380 1992
# Try downloading 476 C1D380 1993
# Try downloading 476 C1D380 1994
# Try downloading 476 C1D380 1995
# Try downloading 476 C1D380 1996
# Try downloading 476 C1D380 1997
# Try downloading 476 C1D380 1998
# Try downloading 476 C1D380 1999
# Try downloading 476 C1D380 2000
# Try downloading 476 C1D380 2001
# Try downloading 476 C1D380 2002
# Try downloading 476 C1D380 2003
# Try downloading 476 C1D380 2004
# Try downloading 476 C1D380 2005
# Try downloading 476 C1D380 2006
# Try downloading 476 C1D380 2007
# Try downloading 476 C1D380 2008
# Try downloading 476 C1D380 2009
# Try downloading 476 C1D380 2010
# Try downloading 476 C1D380 2011
# Try downloading 476 C1D380 2012
# Try downloading 476 C1D380 2013
# Try downloading 476 C1D380 2014
# Try downloading 476 C1D380 2015
# Try downloading 476 C1D380 2016
# Try downloading 476 C1D380 2017
# Try downloading 476 C1D380 2018
# Try downloading 476 C1D380 2019
# Try downloading 476 C1D380 2020
# Try downloading 476 C1D380 2021
# Try downloading 476 C1D380 2022
# C1D380 1987 downloaded
# C1D380 1994 downloaded
# C1D380 1988 downloaded
# C1D380 C1D380 1992 downloaded
# C1D3801991  1995 downloaded
# downloaded
# C1D380 1989 downloaded
# C1D380 1990 downloadedC1D380
#  1993 downloaded
# C1D380 1996 downloaded
# C1D380 1997 downloaded
# C1D380 1998 downloaded
# C1D380 2000 downloaded
# C1D380 1999 downloaded
# C1D380 2003 downloaded
# C1D380 2002 downloaded
# C1D380 2004 downloaded
# C1D380C1D380 2001 downloaded
#  2005 downloaded
# C1D380 2006 downloaded
# C1D380 2007 downloaded
# C1D380 2008 downloaded
# C1D380 2009 downloaded
# C1D380 2010 downloaded
# C1D380 2012 downloaded
# C1D380 2013 downloaded
# C1D380 2011 downloaded
# C1D380 2016 downloaded
# C1D380 2014 downloaded
# C1D380 2015 downloaded
# C1D380 2022 downloaded
# C1D380 2017 downloaded
# C1D380 2018 downloaded
# C1D380 2020 downloaded
# C1D380 2019 downloaded
# C1D380 2021 downloaded
# Try downloading 477 C1D400 1987
# Try downloading 477 C1D400 1988
# Try downloading 477 C1D400 1989
# Try downloading 477 C1D400 1990
# Try downloading 477 C1D400 1991
# Try downloading 477 C1D400 1992
# Try downloading 477 C1D400 1993
# Try downloading 477 C1D400 1994
# Try downloading 477 C1D400 1995
# Try downloading 477 C1D400 1996
# Try downloading 477 C1D400 1997
# Try downloading 477 C1D400 1998
# Try downloading 477 C1D400 1999
# Try downloading 477 C1D400 2000
# Try downloading 477 C1D400 2001
# Try downloading 477 C1D400 2002
# Try downloading 477 C1D400 2003
# Try downloading 477 C1D400 2004
# Try downloading 477 C1D400 2005
# Try downloading 477 C1D400 2006
# Try downloading 477 C1D400 2007
# Try downloading 477 C1D400 2008
# Try downloading 477 C1D400 2009
# Try downloading 477 C1D400 2010
# Try downloading 477 C1D400 2011
# Try downloading 477 C1D400 2012
# Try downloading 477 C1D400 2013
# Try downloading 477 C1D400 2014
# Try downloading 477 C1D400 2015
# Try downloading 477 C1D400 2016
# Try downloading 477 C1D400 2017
# Try downloading 477 C1D400 2018
# Try downloading 477 C1D400 2019
# Try downloading 477 C1D400 2020
# Try downloading 477 C1D400 2021
# Try downloading 477 C1D400 2022
# C1D400 1987 downloaded
# C1D400 1993 downloaded
# C1D400 1988 C1D400 1992 downloaded
# downloaded
# C1D400 1989 downloaded
# C1D400 C1D4001996  1994downloaded
# downloaded
# C1D400 1991 downloaded
# C1D400 1990 downloaded
# C1D400 1995 downloaded
# C1D400 1997 downloaded
# C1D400 2000 downloaded
# C1D400 2004 downloaded
# C1D400 1999 downloaded
# C1D400 2002 downloaded
# C1D400 1998 downloaded
# C1D400C1D400 2005 downloaded
#  2003 downloaded
# C1D400 2001 downloaded
# C1D400 2006 downloaded
# C1D400 2007 downloaded
# C1D400 2009 downloaded
# C1D400 2010 downloaded
# C1D400 2011 downloaded
# C1D400 2014 downloaded
# C1D400 2013 downloaded
# C1D400 2008 downloaded
# C1D400 2015 downloaded
# C1D400 2012 downloaded
# C1D400 2016 downloaded
# C1D400 2017 downloaded
# C1D400 2022 downloaded
# C1D400 2018 downloaded
# C1D400 2019 downloaded
# C1D400 2021 downloaded
# C1D400 2020 downloaded
# Try downloading 478 C1D410 1987
# Try downloading 478 C1D410 1988
# Try downloading 478 C1D410 1989
# Try downloading 478 C1D410 1990
# Try downloading 478 C1D410 1991
# Try downloading 478 C1D410 1992
# Try downloading 478 C1D410 1993
# Try downloading 478 C1D410 1994
# Try downloading 478 C1D410 1995
# Try downloading 478 C1D410 1996
# Try downloading 478 C1D410 1997
# Try downloading 478 C1D410 1998
# Try downloading 478 C1D410 1999
# Try downloading 478 C1D410 2000
# Try downloading 478 C1D410 2001
# Try downloading 478 C1D410 2002
# Try downloading 478 C1D410 2003
# Try downloading 478 C1D410 2004
# Try downloading 478 C1D410 2005
# Try downloading 478 C1D410 2006
# Try downloading 478 C1D410 2007
# Try downloading 478 C1D410 2008
# Try downloading 478 C1D410 2009
# Try downloading 478 C1D410 2010
# Try downloading 478 C1D410 2011
# Try downloading 478 C1D410 2012
# Try downloading 478 C1D410 2013
# Try downloading 478 C1D410 2014
# Try downloading 478 C1D410 2015
# Try downloading 478 C1D410 2016
# Try downloading 478 C1D410 2017
# Try downloading 478 C1D410 2018
# Try downloading 478 C1D410 2019
# Try downloading 478 C1D410 2020
# Try downloading 478 C1D410 2021
# Try downloading 478 C1D410 2022
# C1D410 1987 downloaded
# C1D410 1993 downloaded
# C1D410 1989 downloaded
# C1D410 1994 downloaded
# C1D410 1990 downloaded
# C1D410 1991 downloaded
# C1D410 1992 downloaded
# C1D410 1995 downloaded
# C1D410 1996 downloaded
# C1D410 1988 downloaded
# C1D410 1997 downloaded
# C1D410 1999 downloaded
# C1D410 2000 downloaded
# C1D410 2006 downloaded
# C1D410 C1D410 2002 downloaded
# 1998 downloaded
# C1D410 2001 downloaded
# C1D410 2005 downloaded
# C1D410 2003 downloaded
# C1D410 2004 downloaded
# C1D410 2007 downloaded
# C1D410 2008 downloaded
# C1D410 2012 downloaded
# C1D410 2009 downloaded
# C1D410 2010 downloaded
# C1D410 2011 downloaded
# C1D410 2014 downloaded
# C1D410 2015 downloaded
# C1D410 2013 downloaded
# C1D410 2016 downloaded
