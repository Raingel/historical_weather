# %%
from google.colab import drive
drive.mount('/content/drive')
ROOT = './'
ROOT='/content/drive/MyDrive/Colab Notebooks/historical_weather'
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import requests
from dateutil.parser import parse
import json
from datetime import datetime, timedelta
import os

# %%
def agr_get_sta_list(area_id=0, level_id=0):
    my_headers = {    
        "accept": "application/json, text/javascript, */*; q=0.01",
        "accept-language": "ja-JP,ja;q=0.9,zh-TW;q=0.8,zh;q=0.7,en-US;q=0.6,en;q=0.5",
        "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
        "sec-ch-ua": "\"Chromium\";v=\"92\", \" Not A;Brand\";v=\"99\", \"Google Chrome\";v=\"92\"",
        "sec-ch-ua-mobile": "?0",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "x-requested-with": "XMLHttpRequest", #required
    }
    URI = 'https://agr.cwb.gov.tw/NAGR/history/station_day/get_station_name'
    area = ['', '北', '中', '南', '東'][area_id]
    level = ['自動站', '新農業站'][level_id]
    r1 = requests.post(URI, data={'area':area, 'level':level}, headers = my_headers)
    sta_dict = json.loads(r1.text)
    df = pd.DataFrame(sta_dict)
    extract_df = df[['ID', 'Cname', 'Altitude', 'Latitude_WGS84', 'Longitude_WGS84', 'Address', 'StnBeginTime', 'stnendtime', 'stationlist_auto']]
    extract_df.columns=['站號', '站名', '海拔高度(m)', '緯度', '經度', '地址', '資料起始日期', '撤站日期', '備註']
    return extract_df
def load_weather_station_list(include_suspended = False, include_agr_sta = True):
    #load from CWB
    raw = pd.read_html('https://e-service.cwb.gov.tw/wdps/obs/state.htm')
    weather_station_list = raw[0]
    if include_suspended:
        weather_station_list =  weather_station_list.append(raw[1])
    #load from agri
    if include_agr_sta:
        weather_station_list = weather_station_list.append(agr_get_sta_list(level_id=1), ignore_index = True)
    return weather_station_list

# %%
#Fetch From https://agr.cwb.gov.tw/NAGR/history/station_day
my_headers = {    
    "accept": "application/json, text/javascript, */*; q=0.01",
    "accept-language": "ja-JP,ja;q=0.9,zh-TW;q=0.8,zh;q=0.7,en-US;q=0.6,en;q=0.5",
    "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
    "sec-ch-ua": "\"Chromium\";v=\"92\", \" Not A;Brand\";v=\"99\", \"Google Chrome\";v=\"92\"",
    "sec-ch-ua-mobile": "?0",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "x-requested-with": "XMLHttpRequest", #required
}

def agr_get_hour_data (station = '466910', start_time = '2021-08-24', end_time = '2021-08-24', items=['PrecpHour']):
    get_hour = "https://agr.cwb.gov.tw/NAGR/history/station_hour/get_station_hour"
    #資料有可能存在「自動站」的資料庫
    #資料庫對自動站及農業站的日期處理行為不同
    start_time_dt = parse(start_time)
    end_time_dt = parse(end_time)
    r1 = requests.post(get_hour, data = {'station' : station, 'start_time': start_time_dt.strftime('%Y%m%d'), 'end_time': end_time_dt.strftime('%Y%m%d'), 'items[]': items, 'level': ''}, headers = my_headers)
    r2 = requests.post(get_hour, data = {'station' : station, 'start_time': start_time_dt.strftime('%Y%m%d'), 'end_time': end_time_dt.strftime('%Y%m%d'), 'items[]': items, 'level': '自動站'}, headers = my_headers)
    #return r1.text,r2.text
    #Try parsing return data
    try:
        r1_parsed = json.loads(r1.text)['result']
    except Exception as e:
        r1_parsed=[]
        print('r1 parse error: ',e, r1.text)
        
    try:
        r2_parsed = json.loads(r2.text)['result']
    except Exception as e:
        r2_parsed=[]
        print('r2 parse error: ',e, r2.text)

    
    #only one of r1 and r2 will contain required data
    if r1_parsed != []:
        #print (station, "為農業站")
        return r1_parsed
    if r2_parsed != []:
        #print (station, "為自動站")
        return r2_parsed
    return []


def agr_get_items (station = '466910'): #check available fields
    get_items_URI = "https://agr.cwb.gov.tw/NAGR/history/station_day/get_items"
    r = requests.post(get_items_URI, data = {'station': station},  headers= my_headers)
    try:
        return json.loads(r.text)['columns']
    except:
        return r.text
    
def agr_parsing (f):
    try:
        rt = list(f.values())[0]
        rt = float(rt)
        if rt < -90:
            return -999
        return rt
    except Exception as e:
        return -999
    
    
def agr_fetch (station_num=467080, date='2021-08-16'):
    output_columns = {
        'StaNO': '站號',
        'ObsTime': '觀測時間(hour)',
        'StnPres': '測站氣壓(hPa)',
        'SeaPres': '海平面氣壓(hPa)',
        'Tx': '氣溫(℃)',
        'Td': '露點溫度(℃)',
        'RH': '相對溼度(%)',
        'WS': '風速(m/s)',
        'WD': '風向(360degree)',
        'WSGust': '最大陣風(m/s)',
        'WDGust': '最大陣風風向(360degree)',
        'Precp': '降水量(mm)',
        'PrecpHr': '降水時數(hr)',
        'SunShine': '日照時數(hr)',
        'GloblRad': '全天空日射量(MJ/㎡)',
        'Visb': '能見度(km)',
        'UVI': '紫外線指數',
        'Cloud':'總雲量(0~10)'}
    #initialize the dataFrame
    station='C0Z200'
    df = pd.DataFrame(columns = output_columns.values())
    #如果items裡面放了他資料庫沒有的東西，會發生錯誤。所以得自己先確認交集
    sta_item = set(output_columns.keys()).intersection(agr_get_items(station_num))
    d = agr_get_hour_data(station=station_num,start_time=date, end_time=date, items=sta_item)
    df['觀測時間(hour)'] = pd.date_range(date+' 01:00:00', periods=24, freq='1h')
    df['站號'] = station_num
    df.set_index('觀測時間(hour)', inplace=True)
    #if no valid data
    if (d==[]):
        return pd.DataFrame()
    for single_factor in d:
        for rec in single_factor:
            #{'StnPres': '924.4', 'ObsTime': '2020-08-15 02:00:00'}
            ObsTime = parse(rec['ObsTime'])
            #in case of 8/16 23:59:00
            if ObsTime.strftime('%H%M')=='2359':
                ObsTime += timedelta(minutes=1)
            del rec['ObsTime']
            #After deleting ObsTime, the last key left is the observation data
            col_code = list(rec)[0]
            col_name = output_columns[col_code]
            #fill the data into the table
            df.loc[ObsTime,col_name] = rec[col_code]

    df.fillna(-999, inplace=True)
    df.reset_index(inplace=True)
    #dt need to be converted to str before enter MySQL
    df['觀測時間(hour)'] = df['觀測時間(hour)'].dt.strftime('%Y-%m-%d %H:%i:%s')
    
    return df

def agr_fetch_year_full (station_num=467080, year='2021', save_path = ''):
    sta_item = agr_get_items(station_num)
    df = pd.DataFrame()
    for month in range(1,13):
        start_time = '{}/{}/{}'.format(year,month,'1')
        if month == 12:
            end_time = '{}/{}/{}'.format(year,month,'31')
        else:
            end_time = (parse('{}/{}/{}'.format(year,month + 1,'1')) - timedelta(days = 1)).strftime('%Y/%m/%d')
        data_list = agr_get_hour_data(station=station_num,start_time=start_time, end_time=end_time, items=sta_item)
        df = df.append(agr_factor_to_df(data_list))     
    if save_path != '':
        df.to_csv(save_path, encoding = 'utf-8-sig')
    print(station_num, year,'downloaded')
    return df
    
def add_1min_to_2359 (d):
    if d.strftime('%H%M')=='2359':
        d += timedelta(minutes=1)
    return d

def agr_factor_to_df (d):
    df = pd.DataFrame()
    for r in d:
       
        keys = list(r[0])
        keys.remove('ObsTime')
        #There will be two keys in the data, one is the observation time, and the other is the query data
        factor_key = keys[0]
        data = [row[factor_key] for row in r]
        ObsTime = [parse(row['ObsTime']) for row in r]
        ObsTime = list(map(add_1min_to_2359 , ObsTime))
        df_temp = pd.DataFrame(index = ObsTime)
        #df_temp.index = ObsTime
        df_temp[factor_key] = data
        if df.empty:
            df = df_temp.copy()
        else: 
            df = pd.merge(df, df_temp, left_index=True, right_index=True, how='outer')
    return df

# %%
sta_list = load_weather_station_list(include_suspended = True)

# %%
import concurrent.futures

# %%
for index, row in sta_list[1:].iterrows():
    sta_info = {}
    sta_info ['sta_no'] = row[0]
    sta_info ['sta_name'] = row[1]
    sta_info ['start'] = parse(row[7])
    try:
        sta_info ['end'] = parse(row[8])
    except Exception as e:
        sta_info ['end'] = datetime.today()
    DIR_PATH = os.path.join(ROOT,'data',sta_info ['sta_no'])
    os.makedirs(DIR_PATH, exist_ok=True)
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures=[]
        for year in range(sta_info['start'].year, sta_info['end'].year +1):
            CSV_PATH = os.path.join(DIR_PATH,sta_info['sta_no']+'_'+str(year)+'.csv')
            try:
                #Check if file is already downloded
                if os.path.isfile(CSV_PATH) == False:
                    print ('Try downloading',index, sta_info['sta_no'], year)
                    future = executor.submit(
                                                agr_fetch_year_full, sta_info['sta_no'], 
                                                year, 
                                                CSV_PATH
                                            )
                    futures.append(future)
                else:
                    print(CSV_PATH, 'already downloaded, skipped')
            except Exception as e:
                print(e)
        #wait job to be finished
        try:
            for future in futures:
                future.result(timeout=300)
        except concurrent.futures.TimeoutError:
            print('Timeout error', future)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# C1S880 2000 downloaded
# C1S880 1998 downloaded
# C1S880 2005 downloaded
# C1S880 2004 downloaded
# C1S880 2001 downloaded
# C1S880 2006 downloaded
# C1S880 2002 downloaded
# C1S880 2007 downloaded
# C1S880 2011 downloaded
# C1S880 2009 downloaded
# C1S880 2008 downloaded
# C1S880 2010 downloaded
# C1S880 2012 downloaded
# C1S880 2013 downloaded
# C1S880 2014 downloaded
# C1S880 2015 downloaded
# C1S880 2016 downloaded
# C1S880 2022 downloaded
# C1S880 2017 downloaded
# C1S880 2020 downloaded
# C1S880 2019 downloaded
# C1S880 2021 downloaded
# C1S880 2018 downloaded
# Try downloading 576 C1SA50 2020
# Try downloading 576 C1SA50 2021
# Try downloading 576 C1SA50 2022
# C1SA50 2022 downloaded
# C1SA50 2020 downloaded
# C1SA50 2021 downloaded
# Try downloading 577 C1SA70 2019
# Try downloading 577 C1SA70 2020
# Try downloading 577 C1SA70 2021
# Try downloading 577 C1SA70 2022
# C1SA70 2022 downloaded
# C1SA70 2019 downloaded
# C1SA70 2020 downloaded
# C1SA70 2021 downloaded
# Try downloading 578 C1T800 1996
# Try downloading 578 C1T800 1997
# Try downloading 578 C1T800 1998
# Try downloading 578 C1T800 1999
# Try downloading 578 C1T800 2000
# Try downloading 578 C1T800 2001
# Try downloading 578 C1T800 2002
# Try downloading 578 C1T800 2003
# Try downloading 578 C1T800 2004
# Try downloading 578 C1T800 2005
# Try downloading 578 C1T800 2006
# Try downloading 578 C1T800 2007
# Try downloading 578 C1T800 2008
# Try downloading 578 C1T800 2009
# Try downloading 578 C1T800 2010
# Try downloading 578 C1T800 2011
# Try downloading 578 C1T800 2012
# Try downloading 578 C1T800 2013
# Try downloading 578 C1T800 2014
# Try downloading 578 C1T800 2015
# Try downloading 578 C1T800 2016
# Try downloading 578 C1T800 2017
# Try downloading 578 C1T800 2018
# Try downloading 578 C1T800 2019
# C1U920 2018 downloaded
# C1U920C1U920 2019 downloaded
#  2020 downloaded
# C1U920 2021 downloaded
# Try downloading 595 C1V160 1992
# Try downloading 595 C1V160 1993
# Try downloading 595 C1V160 1994
# Try downloading 595 C1V160 1995
# Try downloading 595 C1V160 1996
# Try downloading 595 C1V160 1997
# Try downloading 595 C1V160 1998
# Try downloading 595 C1V160 1999
# Try downloading 595 C1V160 2000
# Try downloading 595 C1V160 2001
# Try downloading 595 C1V160 2002
# Try downloading 595 C1V160 2003
# Try downloading 595 C1V160 2004
# Try downloading 595 C1V160 2005
# Try downloading 595 C1V160 2006
# Try downloading 595 C1V160 2007
# Try downloading 595 C1V160 2008
# Try downloading 595 C1V160 2009
# Try downloading 595 C1V160 2010
# Try downloading 595 C1V160 2011
# Try downloading 595 C1V160 2012
# Try downloading 595 C1V160 2013
# Try downloading 595 C1V160 2014
# Try downloading 595 C1V160 2015
# Try downloading 595 C1V160 2016
# Try downloading 595 C1V160 2017
# Try downloading 595 C1V160 2018
# Try downloading 595 C1V160 2019
# Try downloading 595 C1V160 2020
# Try downloading 595 C1V160 2021
# Try downloading 595 C1V160 2022
# C1V160 1992 downloaded
# C1V160 1999 downloaded
# C1V160 2001 downloaded
# C1V160 1994 downloaded
# C1V160 1995 downloaded
# C1V160 1997 downloaded
# C1V160 1996 downloaded
# C1V160C1V160 1993 downloaded
#  2000 downloaded
# C1V160 1998 downloaded
# C1V160 2002 downloaded
# C1V160 2005 downloaded
# C1V160 2006 downloaded
# C1V160 2010 downloaded
# C1V160 2003 downloaded
# C1V160 2008 downloaded
# C1V160 2004 downloaded
# C1V160 2007 downloaded
# C1V160 2009 downloaded
# C1V160 2011 downloaded
# C1V160 2013 downloaded
# C1V160 2015 downloaded
# C1V160 2012 downloaded
# C1V160 2017 downloaded
# C1V160 2014 downloaded
# C1V160 2018 downloaded
# C1V160 2016 downloaded
# C1V160 2019 downloaded
# C1V160 2020 downloaded
# C1V160 2021 downloaded
# C1V160 2022 downloaded
# Try downloading 596 C1V170 1992
# Try downloading 596 C1V170 1993
# Try downloading 596 C1V170 1994
# Try downloading 596 C1V170 1995
# Try downloading 596 C1V170 1996
# Try downloading 596 C1V170 1997
# Try downloading 596 C1V170 1998
# Try downloading 596 C1V170 1999
# Try downloading 596 C1V170 2000
# Try downloading 596 C1V170 2001
# Try downloading 596 C1V170 2002
# Try downloading 596 C1V170 2003
# Try downloading 596 C1V170 2004
# Try downloading 596 C1V170 2005
# Try downloading 596 C1V170 2006
# Try downloading 596 C1V170 2007
# Try downloading 596 C1V170 2008
# Try downloading 596 C1V170 2009
# Try downloading 596 C1V170 2010
# Try downloading 596 C1V170 2011
# Try downloading 596 C1V170 2012
# Try downloading 596 C1V170 2013
# Try downloading 596 C1V170 2014
# Try downloading 596 C1V170 2015
# Try downloading 596 C1V170 2016
# Try downloading 596 C1V170 2017
# Try downloading 596 C1V170 2018
# Try downloading 596 C1V170 2019
# Try downloading 596 C1V170 2020
# Try downloading 596 C1V170 2021
# Try downloading 596 C1V170 2022
# C1V170 1992 downloaded
# C1V170 1995 downloaded
# C1V170 1997 downloaded
# C1V170 2001 downloaded
# C1V170 1996 downloaded
# C1V170 1993 downloaded
# C1V170 1998 downloaded
# C1V170 1999 downloaded
# C1V170 1994 downloaded
# C1V170 2000 downloaded
# C1V170 2003 downloaded
# C1V170 2002 downloaded
# C1V170 2008C1V170 2005 downloaded
#  downloaded
# C1V170 2004 downloaded
# C1V170 2006 downloaded
# C1V170 2011 downloaded
# C1V170 2007 downloaded
# C1V170 2009 downloaded
# C1V170 2010 downloaded
# C1V170 2012 downloaded
# C1V170 2013 downloaded
# C1V170 2017 downloaded
# C1V170 2014 downloaded
# C1V170 2016 downloaded
# C1V170 2015 downloaded
# C1V170 2019 downloaded
# C1V170 2018 downloaded
# C1V170 2020 downloaded
# C1V170 2021 downloaded
# C1V170 2022 downloaded
# Try downloading 597 C1V190 1992
# Try downloading 597 C1V190 1993
# Try downloading 597 C1V190 1994
# Try downloading 597 C1V190 1995
# Try downloading 597 C1V190 1996
# Try downloading 597 C1V190 1997
# Try downloading 597 C1V190 1998
# Try downloading 597 C1V190 1999
# Try downloading 597 C1V190 2000
# Try downloading 597 C1V190 2001
# Try downloading 597 C1V190 2002
# Try downloading 597 C1V190 2003
# Try downloading 597 C1V190 2004
# Try downloading 597 C1V190 2005
# Try downloading 597 C1V190 2006
# Try downloading 597 C1V190 2007
# Try downloading 597 C1V190 2008
# Try downloading 597 C1V190 2009
# Try downloading 597 C1V190 2010
# Try downloading 597 C1V190 2011
# Try downloading 597 C1V190 2012
# Try downloading 597 C1V190 2013
# Try downloading 597 C1V190 2014
# Try downloading 597 C1V190 2015
# Try downloading 597 C1V190 2016
# Try downloading 597 C1V190 2017
# Try downloading 597 C1V190 2018
# Try downloading 597 C1V190 2019
# Try downloading 597 C1V190 2020
# Try downloading 597 C1V190 2021
# Try downloading 597 C1V190 2022
# C1V190 2001 downloaded
# C1V190 1992 downloaded
# C1V190 1998 downloaded
# C1V190 2000 downloaded
# C1V190 1995 downloaded
# C1V190 1993 downloaded
# C1V190 1999 downloaded
# C1V190 1997 downloaded
# C1V190 1996 downloaded
# C1V190 1994 downloaded
# C1V190 2005 downloaded
# C1V190 2003 downloaded
# C1V190 2004 downloaded
# C1V190 2006 downloaded
# C1V190 2002 downloaded
# C1V190 2010 downloaded
# C1V190 2009 downloaded
# C1V190 2008 downloaded
# C1V190 2007 downloaded
# C1V190 2011 downloaded
# C1V190 2014 downloaded
# C1V190 2012 downloaded
# C1V190 2013 C1V190 downloaded
# 2015 downloaded
# C1V190 2016 downloaded
# C1V190 2017 downloaded
# C1V190 2019 downloaded
# C1V190 2018 downloaded
# C1V190 2020 downloaded
# C1V190 2021 downloaded
# C1V190 2022 downloaded
# Try downloading 598 C1V200 1992
# Try downloading 598 C1V200 1993
# Try downloading 598 C1V200 1994
# Try downloading 598 C1V200 1995
# Try downloading 598 C1V200 1996
# Try downloading 598 C1V200 1997
# Try downloading 598 C1V200 1998
# Try downloading 598 C1V200 1999
# Try downloading 598 C1V200 2000
# Try downloading 598 C1V200 2001
# Try downloading 598 C1V200 2002
# Try downloading 598 C1V200 2003
# Try downloading 598 C1V200 2004
# Try downloading 598 C1V200 2005
# Try downloading 598 C1V200 2006
# Try downloading 598 C1V200 2007
# Try downloading 598 C1V200 2008
# Try downloading 598 C1V200 2009
# Try downloading 598 C1V200 2010
# Try downloading 598 C1V200 2011
# Try downloading 598 C1V200 2012
# Try downloading 598 C1V200 2013
# Try downloading 598 C1V200 2014
# Try downloading 598 C1V200 2015
# Try downloading 598 C1V200 2016
# Try downloading 598 C1V200 2017
# Try downloading 598 C1V200 2018
# Try downloading 598 C1V200 2019
# Try downloading 598 C1V200 2020
# Try downloading 598 C1V200 2021
# Try downloading 598 C1V200 2022
# C1V200 1992 downloaded
# C1V200 1998 downloaded
# C1V200 1995 downloaded
# C1V200 1999 downloaded
# C1V200 1997 downloaded
# C1V200 2001 downloaded
# C1V200 1994 downloaded
# C1V200 1993 downloaded
# C1V200 1996 downloaded
# C1V200 2000 downloaded
# C1V200 2002 downloaded
# C1V200 2003 downloaded
# C1V200 2004 downloaded
# C1V200C1V200 2007 downloaded
#  2005 downloaded
# C1V200 2010 downloaded
# C1V200 2008 downloaded
# C1V200 2009 downloaded
# C1V200 2006 downloaded
# C1V200 2011 downloaded
# C1V200 2012 downloaded
# C1V200 2013 downloaded
# C1V200 2018 downloaded
# C1V200 2014 downloaded
# C1V200 2015 downloaded
# C1V200 2016 downloaded
# C1V200 2019 downloaded
# C1V200 2020 downloaded
# C1V200 2021 downloaded
# C1V200 2017 downloaded
# C1V200 2022 downloaded
# Try downloading 599 C1V220 1992
# Try downloading 599 C1V220 1993
# Try downloading 599 C1V220 1994
# Try downloading 599 C1V220 1995
# Try downloading 599 C1V220 1996
# Try downloading 599 C1V220 1997
# Try downloading 599 C1V220 1998
# Try downloading 599 C1V220 1999
# Try downloading 599 C1V220 2000
# Try downloading 599 C1V220 2001
# Try downloading 599 C1V220 2002
# Try downloading 599 C1V220 2003
# Try downloading 599 C1V220 2004
# Try downloading 599 C1V220 2005
# Try downloading 599 C1V220 2006
# Try downloading 599 C1V220 2007
# Try downloading 599 C1V220 2008
# Try downloading 599 C1V220 2009
# Try downloading 599 C1V220 2010
# Try downloading 599 C1V220 2011
# Try downloading 599 C1V220 2012
# Try downloading 599 C1V220 2013
# Try downloading 599 C1V220 2014
# Try downloading 599 C1V220 2015
# Try downloading 599 C1V220 2016
# Try downloading 599 C1V220 2017
# Try downloading 599 C1V220 2018
# Try downloading 599 C1V220 2019
# Try downloading 599 C1V220 2020
# Try downloading 599 C1V220 2021
# Try downloading 599 C1V220 2022
# C1V220 1994 downloaded
# C1V220 1995 downloaded
# C1V220 1992 downloaded
# C1V220 2000 downloaded
# C1V220C1V220 2001 downloaded
#  1996 downloaded
# C1V220 1999 downloaded
# C1V220 1998 downloaded
# C1V220 1997 downloaded
# C1V220 1993 downloaded
# C1V220 2002 downloaded
# C1V220 2003 downloaded
# C1V220 2004 downloaded
# C1V220 2006 downloaded
# C1V220 2005 downloaded
# C1V220 2007 downloaded
# C1V220 2008 downloaded
# C1V220 2010 downloaded
# C1V220 2009 downloaded
# C1V220 2011 downloaded
# C1V220 2012 downloaded
# C1V220 2016 downloaded
# C1V220 2014 downloaded
# C1V220 2013 downloaded
# C1V220 2017 downloaded
# C1V220 2015 downloaded
# C1V220 2018 downloaded
# C1V220 2020 downloaded
# C1V220 2021 downloaded
# C1V220 2019 downloaded
# C1V220 2022 downloaded
# Try downloading 600 C1V231 2013
# Try downloading 600 C1V231 2014
# Try downloading 600 C1V231 2015
# Try downloading 600 C1V231 2016
# Try downloading 600 C1V231 2017
# Try downloading 600 C1V231 2018
# Try downloading 600 C1V231 2019
# Try downloading 600 C1V231 2020
# Try downloading 600 C1V231 2021
# Try downloading 600 C1V231 2022
# C1V231 2022 downloaded
# C1V231 2013 downloaded
# C1V231 2020 downloaded
# C1V231 2016 downloaded
# C1V231 2017 downloaded
# C1V231 2019 downloaded
# C1V231 2015 downloaded
# C1V231 2021 downloaded
# C1V231 2018 downloaded
# C1V231 2014 downloaded
# Try downloading 601 C1V300 1992
# Try downloading 601 C1V300 1993
# Try downloading 601 C1V300 1994
# Try downloading 601 C1V300 1995
# Try downloading 601 C1V300 1996
# Try downloading 601 C1V300 1997
# Try downloading 601 C1V300 1998
# Try downloading 601 C1V300 1999
# Try downloading 601 C1V300 2000
# Try downloading 601 C1V300 2001
# Try downloading 601 C1V300 2002
# Try downloading 601 C1V300 2003
# Try downloading 601 C1V300 2004
# Try downloading 601 C1V300 2005
# Try downloading 601 C1V300 2006
# Try downloading 601 C1V300 2007
# Try downloading 601 C1V300 2008
# Try downloading 601 C1V300 2009
# Try downloading 601 C1V300 2010
# Try downloading 601 C1V300 2011
# Try downloading 601 C1V300 2012
# Try downloading 601 C1V300 2013
# Try downloading 601 C1V300 2014
# Try downloading 601 C1V300 2015
# Try downloading 601 C1V300 2016
# Try downloading 601 C1V300 2017
# Try downloading 601 C1V300 2018
# Try downloading 601 C1V300 2019
# Try downloading 601 C1V300 2020
# Try downloading 601 C1V300 2021
# Try downloading 601 C1V300 2022
# C1V300 1993 downloaded
# C1V300 1995 downloaded
# C1V300 1996 downloaded
# C1V300 1992 downloaded
# C1V300 2000 downloaded
# C1V300C1V300 1998 downloaded
#  2001 downloaded
# C1V300 1994 downloaded
# C1V300 1997 downloaded
# C1V300 1999 downloaded
# C1V300 2002 downloaded
# C1V300 2004 downloaded
# C1V300 2003C1V300 2006  downloaded
# downloaded
# C1V300 2010 downloaded
# C1V300 2005 downloaded
# C1V300 2011 downloaded
# C1V300 2007 downloaded
# C1V300 2009 downloaded
# C1V300 2008 downloaded
# C1V300 2013 downloaded
# C1V300 2012 downloaded
# C1V300 2014 downloaded
# C1V300 2015 downloaded
# C1V300 2016 downloaded
# C1V300 2018 downloaded
# C1V300 2020 downloaded
# C1V300 2019 downloaded
# C1V300 2021 downloaded
# C1V300 2017 downloaded
# C1V300 2022 downloaded
# Try downloading 602 C1V340 1992
# Try downloading 602 C1V340 1993
# Try downloading 602 C1V340 1994
# Try downloading 602 C1V340 1995
# Try downloading 602 C1V340 1996
# Try downloading 602 C1V340 1997
# Try downloading 602 C1V340 1998
# Try downloading 602 C1V340 1999
# Try downloading 602 C1V340 2000
# Try downloading 602 C1V340 2001
# Try downloading 602 C1V340 2002
# Try downloading 602 C1V340 2003
# Try downloading 602 C1V340 2004
# Try downloading 602 C1V340 2005
# Try downloading 602 C1V340 2006
# Try downloading 602 C1V340 2007
# Try downloading 602 C1V340 2008
# Try downloading 602 C1V340 2009
# Try downloading 602 C1V340 2010
# Try downloading 602 C1V340 2011
# Try downloading 602 C1V340 2012
# Try downloading 602 C1V340 2013
# Try downloading 602 C1V340 2014
# Try downloading 602 C1V340 2015
# Try downloading 602 C1V340 2016
# Try downloading 602 C1V340 2017
# Try downloading 602 C1V340 2018
# Try downloading 602 C1V340 2019
# Try downloading 602 C1V340 2020
# Try downloading 602 C1V340 2021
# Try downloading 602 C1V340 2022
# C1V340 2001 downloaded
# C1V340 1999 downloaded
# C1V340 1998 downloaded
# C1V340 1992 downloaded
# C1V340 1993 downloaded
# C1V340 1994 downloaded
# C1V340 2000 downloaded
# C1V340 1997 downloaded
# C1V340 1996 downloaded
# C1V340 1995 downloaded
# C1V340 2002 downloaded
# C1V340 2005 downloaded
# C1V340 2006 downloaded
# C1V340 2007 downloaded
# C1V340 2004 downloaded
# C1V340 2008 downloadedC1V340
#  2009 downloaded
# C1V340 2003 downloaded
# C1V340 2010 downloaded
# C1V340 2011 downloaded
# C1V340 2012 downloaded
# C1V340 2013 downloaded
# C1V340 2014 downloaded
# C1V340 2015 downloaded
# C1V340 2017 downloaded
# C1V340 2019 downloaded
# C1V340 2018 downloaded
# C1V340 2016 downloaded
# C1V340 2020 downloaded
# C1V340 2021 downloaded
# C1V340 2022 downloaded
# Try downloading 603 C1V390 1992
# Try downloading 603 C1V390 1993
# Try downloading 603 C1V390 1994
# Try downloading 603 C1V390 1995
# Try downloading 603 C1V390 1996
# Try downloading 603 C1V390 1997
# Try downloading 603 C1V390 1998
# Try downloading 603 C1V390 1999
# Try downloading 603 C1V390 2000
# Try downloading 603 C1V390 2001
# Try downloading 603 C1V390 2002
# Try downloading 603 C1V390 2003
# Try downloading 603 C1V390 2004
# Try downloading 603 C1V390 2005
# Try downloading 603 C1V390 2006
# Try downloading 603 C1V390 2007
# Try downloading 603 C1V390 2008
# Try downloading 603 C1V390 2009
# Try downloading 603 C1V390 2010
# Try downloading 603 C1V390 2011
# Try downloading 603 C1V390 2012
# Try downloading 603 C1V390 2013
# Try downloading 603 C1V390 2014
# Try downloading 603 C1V390 2015
# Try downloading 603 C1V390 2016
# Try downloading 603 C1V390 2017
# Try downloading 603 C1V390 2018
# Try downloading 603 C1V390 2019
# Try downloading 603 C1V390 2020
# Try downloading 603 C1V390 2021
# Try downloading 603 C1V390 2022
# C1V390C1V390 1997 downloaded
#  1992 downloaded
# C1V390 1994 downloaded
# C1V390 1998 downloaded
# C1V390 2000 downloaded
# C1V390 1996 downloaded
# C1V390 2001 downloaded
# C1V390 1993 downloaded
# C1V390 1995 downloaded
# C1V390 1999 downloaded
# C1V390 2002 downloaded
# C1V390 2005 downloaded
# C1V390 2003 downloaded
# C1V390 2008 downloaded
# C1V390C1V390 2004 downloaded
#  2007 downloaded
# C1V390 2006 downloaded
# C1V390 2009 downloaded
# C1V390 2011 downloaded
# C1V390 2010 downloaded
# C1V390 2013 downloaded
# C1V390 2015 downloaded
# C1V390 2014 downloaded
# C1V390 2012 downloaded
# C1V390 2017 downloaded
# C1V390 2016 downloaded
# C1V390 2019 downloaded
# C1V390 2018 downloaded
# C1V390 2020 downloaded
# C1V390 2021 downloaded
# C1V390 2022 downloaded
# Try downloading 604 C1V570 2013
# Try downloading 604 C1V570 2014
# Try downloading 604 C1V570 2015
# Try downloading 604 C1V570 2016
# Try downloading 604 C1V570 2017
# Try downloading 604 C1V570 2018
# Try downloading 604 C1V570 2019
# Try downloading 604 C1V570 2020
# Try downloading 604 C1V570 2021
# Try downloading 604 C1V570 2022
# C1V570 2022 downloaded
# C1V570 2013 downloaded
# C1V570 2020 downloaded
# C1V570 2016 downloaded
# C1V570C1V570 2021 downloaded
#  2014 downloaded
# C1V570 2017 downloaded
# C1V570 2019 downloaded
# C1V570 2015 downloaded
# C1V570 2018 downloaded
# Try downloading 605 C1V580 2013
# Try downloading 605 C1V580 2014
# Try downloading 605 C1V580 2015
# Try downloading 605 C1V580 2016
# Try downloading 605 C1V580 2017
# Try downloading 605 C1V580 2018
# Try downloading 605 C1V580 2019
# Try downloading 605 C1V580 2020
# Try downloading 605 C1V580 2021
# Try downloading 605 C1V580 2022
# C1V580 2022 downloaded
# C1V580 2013 downloaded
# C1V580 2021 downloaded
# C1V580 2018 downloaded
# C1V580 2014 downloaded
# C1V580 2015 downloaded
# C1V580 2016 downloaded
# C1V580 2020 downloaded
# C1V580 2019 downloaded
# C1V580 2017 downloaded
# Try downloading 606 C1V590 2013
# Try downloading 606 C1V590 2014
# Try downloading 606 C1V590 2015
# Try downloading 606 C1V590 2016
# Try downloading 606 C1V590 2017
# Try downloading 606 C1V590 2018
# Try downloading 606 C1V590 2019
# Try downloading 606 C1V590 2020
# Try downloading 606 C1V590 2021
# Try downloading 606 C1V590 2022
# C1V590 2022 downloaded
# C1V590 2013 downloaded
# C1V590 2016 downloaded
# C1V590 2019 downloaded
# C1V590 2021 downloaded
# C1V590 2018 downloaded
# C1V590 2015 downloaded
# C1V590 2020 downloaded
# C1V590 2017 downloaded
# C1V590 2014 downloaded
# Try downloading 607 C1V600 2013
# Try downloading 607 C1V600 2014
# Try downloading 607 C1V600 2015
# Try downloading 607 C1V600 2016
# Try downloading 607 C1V600 2017
# Try downloading 607 C1V600 2018
# Try downloading 607 C1V600 2019
# Try downloading 607 C1V600 2020
# Try downloading 607 C1V600 2021
# Try downloading 607 C1V600 2022
# C1V600 2022 downloaded
# C1V600 2013 downloaded
# C1V600 C1V6002019  2014 downloaded
# downloaded
# C1V600 2021 downloaded
# C1V600 2015 downloaded
# C1V600 2016 downloaded
# C1V600 2017 downloaded
# C1V600 2018 downloadedC1V600 2020 downloaded
#
# Try downloading 608 C1V780 2013
# Try downloading 608 C1V780 2014
# Try downloading 608 C1V780 2015
# Try downloading 608 C1V780 2016
# Try downloading 608 C1V780 2017
# Try downloading 608 C1V780 2018
# Try downloading 608 C1V780 2019
# Try downloading 608 C1V780 2020
# Try downloading 608 C1V780 2021
# Try downloading 608 C1V780 2022
# C1V780 2013 downloaded
# C1V780 2022 downloaded
# C1V780 2014 downloaded
# C1V780 2018 C1V780 2017 downloadeddownloaded
# C1V780 2016 downloaded
#
# C1V780 2020 downloaded
# C1V780 2015 downloaded
# C1V780 2019 downloaded
# C1V780 2021 downloaded
# Try downloading 609 C1V830 2021
# Try downloading 609 C1V830 2022
# C1V830 2022 downloaded
# C1V830 2021 downloaded
# Try downloading 610 C1X040 1993
# Try downloading 610 C1X040 1994
# Try downloading 610 C1X040 1995
# Try downloading 610 C1X040 1996
# Try downloading 610 C1X040 1997
# Try downloading 610 C1X040 1998
# Try downloading 610 C1X040 1999
# Try downloading 610 C1X040 2000
# Try downloading 610 C1X040 2001
# Try downloading 610 C1X040 2002
# Try downloading 610 C1X040 2003
# Try downloading 610 C1X040 2004
# Try downloading 610 C1X040 2005
# Try downloading 610 C1X040 2006
# Try downloading 610 C1X040 2007
# Try downloading 610 C1X040 2008
# Try downloading 610 C1X040 2009
# Try downloading 610 C1X040 2010
# Try downloading 610 C1X040 2011
# Try downloading 610 C1X040 2012
# Try downloading 610 C1X040 2013
# Try downloading 610 C1X040 2014
# Try downloading 610 C1X040 2015
# Try downloading 610 C1X040 2016
# Try downloading 610 C1X040 2017
# Try downloading 610 C1X040 2018
# Try downloading 610 C1X040 2019
# Try downloading 610 C1X040 2020
# Try downloading 610 C1X040 2021
# Try downloading 610 C1X040 2022
# C1X040 1993 downloaded
# C1X040 2001 downloaded
# C1X040 2002 downloaded
# C1X040 1994C1X040 downloaded
#  2000 downloaded
# C1X040 1997 downloaded
# C1X040C1X040 1999 downloaded
#  1995 downloaded
# C1X040 1996 downloaded
# C1X040 1998 downloaded
# C1X040C1X040 2005 downloaded
#  2004 downloaded
# C1X040 2003 downloaded
# C1X040 2008 downloaded
# C1X040 2009 downloaded
# C1X040 2010 downloaded
# C1X040C1X040 2006 downloaded
#  2007 downloaded
# C1X040 2011 downloaded
# C1X040 2012 downloaded
# C1X040 2015 downloaded
# C1X040 2022 downloaded
# C1X040 2014 downloaded
# C1X040 2017 downloaded
# C1X040 2020 downloaded
# C1X040 2018 downloaded
# C1X040 2013 downloaded
# C1X040 2019 downloaded
# C1X040 2021 downloaded
# C1X040 2016 downloaded
# Try downloading 611 C1Z030 1997
# Try downloading 611 C1Z030 1998
# Try downloading 611 C1Z030 1999
# Try downloading 611 C1Z030 2000
# Try downloading 611 C1Z030 2001
# Try downloading 611 C1Z030 2002
# Try downloading 611 C1Z030 2003
# Try downloading 611 C1Z030 2004
# Try downloading 611 C1Z030 2005
# Try downloading 611 C1Z030 2006
# Try downloading 611 C1Z030 2007
# Try downloading 620 467570 1939
# Try downloading 620 467570 1940
# Try downloading 620 467570 1941
# Try downloading 620 467570 1942
# Try downloading 620 467570 1943
# Try downloading 620 467570 1944
# Try downloading 620 467570 1945
# Try downloading 620 467570 1946
# Try downloading 620 467570 1947
# Try downloading 620 467570 1948
# Try downloading 620 467570 1949
# Try downloading 620 467570 1950
# Try downloading 620 467570 1951
# Try downloading 620 467570 1952
# Try downloading 620 467570 1953
# Try downloading 620 467570 1954
# Try downloading 620 467570 1955
# Try downloading 620 467570 1956
# Try downloading 620 467570 1957
# Try downloading 620 467570 1958
# Try downloading 620 467570 1959
# Try downloading 620 467570 1960
# Try downloading 620 467570 1961
# Try downloading 620 467570 1962
# Try downloading 620 467570 1963
# Try downloading 620 467570 1964
# Try downloading 620 467570 1965
# Try downloading 620 467570 1966
# Try downloading 620 467570 1967
# Try downloading 620 467570 1968
# Try downloading 620 467570 1969
# Try downloading 620 467570 1970
# Try downloading 620 467570 1971
# Try downloading 620 467570 1972
# Try downloading 620 467570 1973
# Try downloading 620 467570 1974
# Try downloading 620 467570 1975
# Try downloading 620 467570 1976
# Try downloading 620 467570 1977
# Try downloading 620 467570 1978
# Try downloading 620 467570 1979
# Try downloading 620 467570 1980
# Try downloading 620 467570 1981
# Try downloading 620 467570 1982
# Try downloading 620 467570 1983
# Try downloading 620 467570 1984
# Try downloading 620 467570 1985
# Try downloading 620 467570 1986
# Try downloading 620 467570 1987
# Try downloading 620 467570 1988
# Try downloading 620 467570 1989
# Try downloading 620 467570 1990
# Try downloading 620 467570 1991
# 467570 1945 downloaded
# 467570 1947 downloaded
# 467570 1946 downloaded
# 467570 1938 downloaded
# 467570 1939 downloaded
# 467570 1941 downloaded
# 467570 1944 downloaded
# 467570 1943 downloaded
# 467570 1940 downloaded
# 467570 1942 downloaded
# 467570 1949 downloaded
# 467570 1948 downloaded
# 467570 1955 downloaded
# 467570 1951 downloaded
# 467570 1952 downloaded
# 467570 1956 downloaded
# 467570 1953 downloaded
# 467570 1954 downloaded
# 467570 1950 downloaded
# 467570 1957 downloaded
# 467570 1959 downloaded
# 467570 1962 downloaded
# 467570 1963 downloaded
# 467570 1960 downloaded
# 467570 1958 downloaded
# 467570 1961 downloaded
# 467570 1964 downloaded
# 467570 1965 downloaded
# 467570 1966 downloaded
# 467570 1967 downloaded
# 467570 1968 downloaded
# 467570 1970 downloaded
# 467570 1972 downloaded
# 467570 1971 downloaded
# 467570 1969 downloaded
# 467570 1973 downloaded
# 467570 1975 downloaded
# 467570 1974 downloaded
# 467570 1976 downloaded
# 467570 1977 downloaded
# 467570 1978 downloaded
# 467570 1979 downloaded
# 467570 1982 downloaded
# 467570 1984 downloaded
# 467570 1980 downloaded
# ...
#  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# C0S720 2002 downloaded
# C0S720 2006 downloaded
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# C0S720 2005 downloaded
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# C0S720 1997 downloaded
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# C0S720 2003 downloaded
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error: r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  C0S720 2001 downloaded
# list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# C0S720 1998 downloaded
#  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# C0S720 1999 downloaded
# C0S720 2000 downloaded
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# r2 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# C0S720 2007 downloaded
# r1 parse error:  list indices must be integers or slices, not str ["\u89c0\u6e2c\u9805\u76ee\u4e0d\u80fd\u7a7a\u767d"]
# Try downloading 685 C0U640 1998
# Try downloading 685 C0U640 1999
# Try downloading 685 C0U640 2000
# Try downloading 685 C0U640 2001
# Try downloading 685 C0U640 2002
# Try downloading 685 C0U640 2003
# Try downloading 685 C0U640 2004
# Try downloading 685 C0U640 2005
# Try downloading 685 C0U640 2006
# Try downloading 685 C0U640 2007
# Try downloading 685 C0U640 2008
# Try downloading 685 C0U640 2009
# Try downloading 685 C0U640 2010
# Try downloading 685 C0U640 2011
# Try downloading 685 C0U640 2012
# Try downloading 685 C0U640 2013
# Try downloading 685 C0U640 2014
# Try downloading 685 C0U640 2015
# C0U640 2000 downloaded
# C0U640 1997 downloaded
# C0U640 2001 downloaded
# C0U640 1999 downloaded
# C0U640 2005 downloaded
# C0U640 2003 downloaded
# C0U640 2002 downloaded
# C0U640 1998 downloaded
# C0U640 1996 downloaded
# C0U640 2004 downloaded
# C0U640 2007 downloaded
# C0U640 2006 downloaded
# C0U640 2008 downloaded
# C0U640 2009 downloaded
# C0U640 2014 downloaded
# C0U640 2012 downloaded
# C0U640 2013 downloaded
# C0U640 2010 downloaded
# C0U640 2011 downloaded
# C0U640 2015 downloaded
# Try downloading 686 C0U680 2010
# Try downloading 686 C0U680 2011
# Try downloading 686 C0U680 2012
# Try downloading 686 C0U680 2013
# Try downloading 686 C0U680 2014
# Try downloading 686 C0U680 2015
# Try downloading 686 C0U680 2016
# Try downloading 686 C0U680 2017
# C0U680 2017 downloaded
# C0U680 2011 downloaded
# C0U680 2015 downloaded
# C0U680 2013 downloaded
# C0U680 2014 downloaded
# C0U680 2010 downloaded
# C0U680 2016 downloaded
# C0U680 2012 downloaded
# Try downloading 687 C0U730 1996
# Try downloading 687 C0U730 1997
# Try downloading 687 C0U730 1998
# Try downloading 687 C0U730 1999
# Try downloading 687 C0U730 2000
# Try downloading 687 C0U730 2001
# Try downloading 687 C0U730 2002
# Try downloading 687 C0U730 2003
# Try downloading 687 C0U730 2004
# Try downloading 687 C0U730 2005
# Try downloading 687 C0U730 2006
# Try downloading 687 C0U730 2007
# Try downloading 687 C0U730 2008
# Try downloading 687 C0U730 2009
# Try downloading 687 C0U730 2010
# Try downloading 687 C0U730 2011
# Try downloading 687 C0U730 2012
# Try downloading 687 C0U730 2013
# Try downloading 687 C0U730 2014
# Try downloading 687 C0U730 2015
# Try downloading 687 C0U730 2016
# Try downloading 687 C0U730 2017
# C0U730 1998 downloaded
# C0U730 2002 downloaded
# C0U730 2005 downloaded
# C0U730 2004 downloaded
# C0U730 2000 downloaded
# C0U730 1999 downloaded
# C0U730 2003 downloaded
# C0U730 2001 downloaded
# C0U730 1997 downloaded
# C0U730 1996 downloaded
# C0U730 2006 downloaded
# C0U730 2010 downloaded
# C0U730 2007 downloaded
# C0U730 2012 downloaded
# C0U730 2009 downloaded
# C0U730 2011 downloaded
# C0U730 2015 downloaded
# C0U730 2013 downloaded
# C0U730 2008 downloaded
# C0U730 2014 downloaded
# C0U730 2016 downloaded
# C0U730 2017 downloaded
# Try downloading 688 C0V150 1988
# Try downloading 688 C0V150 1989
# Try downloading 688 C0V150 1990
# Try downloading 688 C0V150 1991
# Try downloading 688 C0V150 1992
# Try downloading 688 C0V150 1993
# Try downloading 688 C0V150 1994
# Try downloading 688 C0V150 1995
# Try downloading 688 C0V150 1996
# Try downloading 688 C0V150 1997
# Try downloading 688 C0V150 1998
# Try downloading 688 C0V150 1999
# Try downloading 688 C0V150 2000
# Try downloading 688 C0V150 2001
# Try downloading 688 C0V150 2002
# Try downloading 688 C0V150 2003
# Try downloading 688 C0V150 2004
# Try downloading 688 C0V150 2005
# Try downloading 688 C0V150 2006
# Try downloading 688 C0V150 2007
# Try downloading 688 C0V150 2008
# Try downloading 688 C0V150 2009
# Try downloading 688 C0V150 2010
# Try downloading 688 C0V150 2011
# Try downloading 688 C0V150 2012
# Try downloading 688 C0V150 2013
# Try downloading 688 C0V150 2014
# Try downloading 688 C0V150 2015
# Try downloading 688 C0V150 2016
# Try downloading 688 C0V150 2017
# Try downloading 688 C0V150 2018
# C0V150 1988 downloaded
# C0V150 1994 downloaded
# C0V150 1997 downloaded
# C0V150 1990 downloaded
# C0V150 1993 downloaded
# C0V150 1996 downloaded
# C0V150 1992 downloaded
# C0V150 1989 downloaded
# C0V150 1991 downloaded
# C0V150 1995 downloaded
# C0V150 1998 downloaded
# C0V150 1999 downloaded
# C0V150 2000 downloaded
# C0V150 2001 downloaded
# C0V150 2002 downloaded
# C0V150 2003 downloaded
# C0V150C0V150 2006 downloaded
#  2004 downloaded
# C0V150 2005 downloaded
# C0V150 2007 downloaded
# C0V150 2008 downloaded
# C0V150 2013 downloaded
# C0V150 2018 downloaded
# C0V150 2009 downloaded
# C0V150 2011 downloaded
# C0V150 2010 downloaded
# C0V150 2015 downloaded
# C0V150 2014 downloaded
# C0V150 2016 downloaded
# C0V150 2012 downloaded
# C0V150 2017 downloaded
# Try downloading 689 C0V430 2013
# Try downloading 689 C0V430 2014
# Try downloading 689 C0V430 2015
# C0V430 2013 downloaded
# C0V430 2015 downloaded
# C0V430 2014 downloaded
# Try downloading 690 C0X020 1993
# Try downloading 690 C0X020 1994
# Try downloading 690 C0X020 1995
# Try downloading 690 C0X020 1996
# Try downloading 690 C0X020 1997
# Try downloading 690 C0X020 1998
# Try downloading 690 C0X020 1999
# Try downloading 690 C0X020 2000
# Try downloading 690 C0X020 2001
# Try downloading 690 C0X020 2002
# Try downloading 690 C0X020 2003
# Try downloading 690 C0X020 2004
# Try downloading 690 C0X020 2005
# Try downloading 690 C0X020 2006
# Try downloading 690 C0X020 2007
# Try downloading 690 C0X020 2008
# Try downloading 690 C0X020 2009
# Try downloading 690 C0X020 2010
# Try downloading 690 C0X020 2011
# Try downloading 690 C0X020 2012
# Try downloading 690 C0X020 2013
# Try downloading 690 C0X020 2014
# Try downloading 690 C0X020 2015
# C0X020 1993 downloaded
# C0X020 1999 downloaded
# C0X020 1995 downloaded
# C0X020 2002 downloaded
# C0X020 1996 downloaded
# C0X020 1997 downloaded
# C0X020 2000 downloaded
# C0X020 1994 downloaded
# C0X020 2001 downloaded
