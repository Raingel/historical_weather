# %%
from google.colab import drive
drive.mount('/content/drive')
ROOT = './'
ROOT='/content/drive/MyDrive/Colab Notebooks/historical_weather'
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import requests
from dateutil.parser import parse
import json
from datetime import datetime, timedelta
import os

# %%
def agr_get_sta_list(area_id=0, level_id=0):
    my_headers = {    
        "accept": "application/json, text/javascript, */*; q=0.01",
        "accept-language": "ja-JP,ja;q=0.9,zh-TW;q=0.8,zh;q=0.7,en-US;q=0.6,en;q=0.5",
        "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
        "sec-ch-ua": "\"Chromium\";v=\"92\", \" Not A;Brand\";v=\"99\", \"Google Chrome\";v=\"92\"",
        "sec-ch-ua-mobile": "?0",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "x-requested-with": "XMLHttpRequest", #required
    }
    URI = 'https://agr.cwb.gov.tw/NAGR/history/station_day/get_station_name'
    area = ['', '北', '中', '南', '東'][area_id]
    level = ['自動站', '新農業站'][level_id]
    r1 = requests.post(URI, data={'area':area, 'level':level}, headers = my_headers)
    sta_dict = json.loads(r1.text)
    df = pd.DataFrame(sta_dict)
    extract_df = df[['ID', 'Cname', 'Altitude', 'Latitude_WGS84', 'Longitude_WGS84', 'Address', 'StnBeginTime', 'stnendtime', 'stationlist_auto']]
    extract_df.columns=['站號', '站名', '海拔高度(m)', '緯度', '經度', '地址', '資料起始日期', '撤站日期', '備註']
    return extract_df
def load_weather_station_list(include_suspended = False, include_agr_sta = True):
    #load from CWB
    raw = pd.read_html('https://e-service.cwb.gov.tw/wdps/obs/state.htm')
    weather_station_list = raw[0]
    if include_suspended:
        weather_station_list =  weather_station_list.append(raw[1])
    #load from agri
    if include_agr_sta:
        weather_station_list = weather_station_list.append(agr_get_sta_list(level_id=1), ignore_index = True)
    return weather_station_list

# %%
#Fetch From https://agr.cwb.gov.tw/NAGR/history/station_day
my_headers = {    
    "accept": "application/json, text/javascript, */*; q=0.01",
    "accept-language": "ja-JP,ja;q=0.9,zh-TW;q=0.8,zh;q=0.7,en-US;q=0.6,en;q=0.5",
    "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
    "sec-ch-ua": "\"Chromium\";v=\"92\", \" Not A;Brand\";v=\"99\", \"Google Chrome\";v=\"92\"",
    "sec-ch-ua-mobile": "?0",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "x-requested-with": "XMLHttpRequest", #required
}

def agr_get_hour_data (station = '466910', start_time = '2021-08-24', end_time = '2021-08-24', items=['PrecpHour']):
    get_hour = "https://agr.cwb.gov.tw/NAGR/history/station_hour/get_station_hour"
    #資料有可能存在「自動站」的資料庫
    #資料庫對自動站及農業站的日期處理行為不同
    start_time_dt = parse(start_time)
    end_time_dt = parse(end_time)
    r1 = requests.post(get_hour, data = {'station' : station, 'start_time': start_time_dt.strftime('%Y%m%d'), 'end_time': end_time_dt.strftime('%Y%m%d'), 'items[]': items, 'level': ''}, headers = my_headers)
    r2 = requests.post(get_hour, data = {'station' : station, 'start_time': start_time_dt.strftime('%Y%m%d'), 'end_time': end_time_dt.strftime('%Y%m%d'), 'items[]': items, 'level': '自動站'}, headers = my_headers)
    #return r1.text,r2.text
    #Try parsing return data
    try:
        r1_parsed = json.loads(r1.text)['result']
    except Exception as e:
        r1_parsed=[]
        print('r1 parse error: ',e, r1.text)
        
    try:
        r2_parsed = json.loads(r2.text)['result']
    except Exception as e:
        r2_parsed=[]
        print('r2 parse error: ',e, r2.text)

    
    #only one of r1 and r2 will contain required data
    if r1_parsed != []:
        #print (station, "為農業站")
        return r1_parsed
    if r2_parsed != []:
        #print (station, "為自動站")
        return r2_parsed
    return []


def agr_get_items (station = '466910'): #check available fields
    get_items_URI = "https://agr.cwb.gov.tw/NAGR/history/station_day/get_items"
    r = requests.post(get_items_URI, data = {'station': station},  headers= my_headers)
    try:
        return json.loads(r.text)['columns']
    except:
        return r.text
    
def agr_parsing (f):
    try:
        rt = list(f.values())[0]
        rt = float(rt)
        if rt < -90:
            return -999
        return rt
    except Exception as e:
        return -999
    
    
def agr_fetch (station_num=467080, date='2021-08-16'):
    output_columns = {
        'StaNO': '站號',
        'ObsTime': '觀測時間(hour)',
        'StnPres': '測站氣壓(hPa)',
        'SeaPres': '海平面氣壓(hPa)',
        'Tx': '氣溫(℃)',
        'Td': '露點溫度(℃)',
        'RH': '相對溼度(%)',
        'WS': '風速(m/s)',
        'WD': '風向(360degree)',
        'WSGust': '最大陣風(m/s)',
        'WDGust': '最大陣風風向(360degree)',
        'Precp': '降水量(mm)',
        'PrecpHr': '降水時數(hr)',
        'SunShine': '日照時數(hr)',
        'GloblRad': '全天空日射量(MJ/㎡)',
        'Visb': '能見度(km)',
        'UVI': '紫外線指數',
        'Cloud':'總雲量(0~10)'}
    #initialize the dataFrame
    station='C0Z200'
    df = pd.DataFrame(columns = output_columns.values())
    #如果items裡面放了他資料庫沒有的東西，會發生錯誤。所以得自己先確認交集
    sta_item = set(output_columns.keys()).intersection(agr_get_items(station_num))
    d = agr_get_hour_data(station=station_num,start_time=date, end_time=date, items=sta_item)
    df['觀測時間(hour)'] = pd.date_range(date+' 01:00:00', periods=24, freq='1h')
    df['站號'] = station_num
    df.set_index('觀測時間(hour)', inplace=True)
    #if no valid data
    if (d==[]):
        return pd.DataFrame()
    for single_factor in d:
        for rec in single_factor:
            #{'StnPres': '924.4', 'ObsTime': '2020-08-15 02:00:00'}
            ObsTime = parse(rec['ObsTime'])
            #in case of 8/16 23:59:00
            if ObsTime.strftime('%H%M')=='2359':
                ObsTime += timedelta(minutes=1)
            del rec['ObsTime']
            #After deleting ObsTime, the last key left is the observation data
            col_code = list(rec)[0]
            col_name = output_columns[col_code]
            #fill the data into the table
            df.loc[ObsTime,col_name] = rec[col_code]

    df.fillna(-999, inplace=True)
    df.reset_index(inplace=True)
    #dt need to be converted to str before enter MySQL
    df['觀測時間(hour)'] = df['觀測時間(hour)'].dt.strftime('%Y-%m-%d %H:%i:%s')
    
    return df

def agr_fetch_year_full (station_num=467080, year='2021', save_path = ''):
    sta_item = agr_get_items(station_num)
    df = pd.DataFrame()
    for month in range(1,13):
        start_time = '{}/{}/{}'.format(year,month,'1')
        if month == 12:
            end_time = '{}/{}/{}'.format(year,month,'31')
        else:
            end_time = (parse('{}/{}/{}'.format(year,month + 1,'1')) - timedelta(days = 1)).strftime('%Y/%m/%d')
        data_list = agr_get_hour_data(station=station_num,start_time=start_time, end_time=end_time, items=sta_item)
        df = df.append(agr_factor_to_df(data_list))     
    if save_path != '':
        df.to_csv(save_path, encoding = 'utf-8-sig')
    print(station_num, year,'downloaded')
    return df
    
def add_1min_to_2359 (d):
    if d.strftime('%H%M')=='2359':
        d += timedelta(minutes=1)
    return d

def agr_factor_to_df (d):
    df = pd.DataFrame()
    for r in d:
       
        keys = list(r[0])
        keys.remove('ObsTime')
        #There will be two keys in the data, one is the observation time, and the other is the query data
        factor_key = keys[0]
        data = [row[factor_key] for row in r]
        ObsTime = [parse(row['ObsTime']) for row in r]
        ObsTime = list(map(add_1min_to_2359 , ObsTime))
        df_temp = pd.DataFrame(index = ObsTime)
        #df_temp.index = ObsTime
        df_temp[factor_key] = data
        if df.empty:
            df = df_temp.copy()
        else: 
            df = pd.merge(df, df_temp, left_index=True, right_index=True, how='outer')
    return df

# %%
sta_list = load_weather_station_list(include_suspended = True)

# %%
import concurrent.futures

# %%
for index, row in sta_list[1:].iterrows():
    sta_info = {}
    sta_info ['sta_no'] = row[0]
    sta_info ['sta_name'] = row[1]
    sta_info ['start'] = parse(row[7])
    try:
        sta_info ['end'] = parse(row[8])
    except Exception as e:
        sta_info ['end'] = datetime.today()
    DIR_PATH = os.path.join(ROOT,'data',sta_info ['sta_no'])
    os.makedirs(DIR_PATH, exist_ok=True)
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures=[]
        for year in range(sta_info['start'].year, sta_info['end'].year +1):
            CSV_PATH = os.path.join(DIR_PATH,sta_info['sta_no']+'_'+str(year)+'.csv')
            try:
                #Check if file is already downloded
                if os.path.isfile(CSV_PATH) == False:
                    print ('Try downloading',index, sta_info['sta_no'], year)
                    future = executor.submit(
                                                agr_fetch_year_full, sta_info['sta_no'], 
                                                year, 
                                                CSV_PATH
                                            )
                    futures.append(future)
                else:
                    print(CSV_PATH, 'already downloaded, skipped')
            except Exception as e:
                print(e)
        #wait job to be finished
        try:
            for future in futures:
                future.result(timeout=300)
        except concurrent.futures.TimeoutError:
            print('Timeout error', future)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X110/C0X110_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X110/C0X110_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X110/C0X110_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X110/C0X110_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X110/C0X110_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X110/C0X110_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X110/C0X110_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X120/C0X120_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X120/C0X120_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X120/C0X120_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X120/C0X120_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X120/C0X120_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X120/C0X120_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X120/C0X120_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X120/C0X120_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X120/C0X120_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X120/C0X120_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X130/C0X130_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X130/C0X130_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X130/C0X130_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X130/C0X130_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X130/C0X130_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X130/C0X130_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X130/C0X130_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X130/C0X130_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X130/C0X130_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X130/C0X130_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X140/C0X140_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X140/C0X140_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X140/C0X140_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X140/C0X140_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X140/C0X140_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X140/C0X140_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X140/C0X140_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X140/C0X140_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X140/C0X140_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X140/C0X140_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X150/C0X150_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X150/C0X150_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X150/C0X150_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X150/C0X150_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X150/C0X150_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X150/C0X150_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X150/C0X150_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X150/C0X150_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X150/C0X150_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X150/C0X150_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X160/C0X160_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X160/C0X160_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X160/C0X160_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X160/C0X160_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X160/C0X160_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X160/C0X160_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X160/C0X160_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X160/C0X160_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X160/C0X160_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X160/C0X160_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X170/C0X170_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X170/C0X170_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X170/C0X170_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X170/C0X170_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X170/C0X170_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X170/C0X170_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X170/C0X170_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X170/C0X170_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X170/C0X170_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X170/C0X170_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X180/C0X180_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X180/C0X180_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X180/C0X180_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X180/C0X180_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X180/C0X180_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X180/C0X180_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X180/C0X180_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X180/C0X180_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X180/C0X180_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X180/C0X180_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X190/C0X190_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X190/C0X190_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X190/C0X190_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X190/C0X190_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X190/C0X190_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X190/C0X190_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X190/C0X190_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X190/C0X190_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X190/C0X190_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X190/C0X190_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X200/C0X200_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X200/C0X200_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X200/C0X200_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X200/C0X200_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X200/C0X200_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X200/C0X200_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X200/C0X200_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X200/C0X200_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X200/C0X200_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X200/C0X200_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X210/C0X210_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X210/C0X210_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X210/C0X210_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X210/C0X210_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X210/C0X210_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X210/C0X210_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X210/C0X210_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X210/C0X210_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X220/C0X220_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X220/C0X220_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X220/C0X220_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X220/C0X220_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X220/C0X220_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X220/C0X220_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X220/C0X220_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X220/C0X220_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X230/C0X230_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X230/C0X230_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X230/C0X230_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X230/C0X230_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X230/C0X230_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X230/C0X230_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X230/C0X230_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X230/C0X230_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X240/C0X240_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X240/C0X240_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X240/C0X240_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X240/C0X240_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X240/C0X240_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X240/C0X240_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X240/C0X240_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X240/C0X240_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X250/C0X250_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X250/C0X250_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X250/C0X250_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X250/C0X250_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X250/C0X250_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X250/C0X250_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X250/C0X250_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X250/C0X250_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X260/C0X260_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X260/C0X260_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X260/C0X260_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X260/C0X260_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X260/C0X260_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X260/C0X260_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X260/C0X260_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X260/C0X260_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X280/C0X280_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X280/C0X280_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X280/C0X280_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X280/C0X280_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X280/C0X280_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X280/C0X280_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X280/C0X280_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X280/C0X280_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X290/C0X290_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X290/C0X290_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X290/C0X290_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X290/C0X290_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X290/C0X290_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X290/C0X290_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X290/C0X290_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X300/C0X300_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X300/C0X300_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X300/C0X300_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X300/C0X300_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X300/C0X300_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X300/C0X300_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X300/C0X300_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X310/C0X310_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X310/C0X310_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X310/C0X310_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X310/C0X310_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X310/C0X310_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X310/C0X310_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X310/C0X310_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X320/C0X320_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X320/C0X320_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0X320/C0X320_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z020/C0Z020_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z020/C0Z020_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z020/C0Z020_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z020/C0Z020_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z020/C0Z020_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z020/C0Z020_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z020/C0Z020_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z020/C0Z020_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z020/C0Z020_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z020/C0Z020_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z020/C0Z020_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z020/C0Z020_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z020/C0Z020_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_1997.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_1998.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_1999.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2000.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2001.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2002.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2003.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2004.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2005.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2006.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z050/C0Z050_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z061/C0Z061_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_1997.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_1998.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_1999.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2000.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2001.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2002.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2003.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2004.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2005.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2006.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z070/C0Z070_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z080/C0Z080_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z080/C0Z080_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z080/C0Z080_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z080/C0Z080_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z080/C0Z080_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z080/C0Z080_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z080/C0Z080_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z080/C0Z080_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z080/C0Z080_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z080/C0Z080_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z080/C0Z080_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z100/C0Z100_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z100/C0Z100_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z100/C0Z100_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z100/C0Z100_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z100/C0Z100_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z100/C0Z100_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z100/C0Z100_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z100/C0Z100_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z100/C0Z100_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z150/C0Z150_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z150/C0Z150_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z150/C0Z150_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z150/C0Z150_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z150/C0Z150_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z150/C0Z150_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z160/C0Z160_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z160/C0Z160_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z160/C0Z160_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z160/C0Z160_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z160/C0Z160_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z160/C0Z160_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z170/C0Z170_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z170/C0Z170_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z170/C0Z170_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z170/C0Z170_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z170/C0Z170_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z170/C0Z170_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z180/C0Z180_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z180/C0Z180_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z180/C0Z180_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z180/C0Z180_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z180/C0Z180_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z180/C0Z180_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z190/C0Z190_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z190/C0Z190_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z190/C0Z190_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z190/C0Z190_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z190/C0Z190_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z190/C0Z190_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z200/C0Z200_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z200/C0Z200_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z200/C0Z200_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z200/C0Z200_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z200/C0Z200_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z200/C0Z200_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z210/C0Z210_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z210/C0Z210_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z210/C0Z210_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z210/C0Z210_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z210/C0Z210_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z210/C0Z210_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z220/C0Z220_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z220/C0Z220_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z220/C0Z220_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z220/C0Z220_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z220/C0Z220_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z230/C0Z230_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z230/C0Z230_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z230/C0Z230_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z230/C0Z230_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z230/C0Z230_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z230/C0Z230_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z250/C0Z250_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z250/C0Z250_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z250/C0Z250_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z250/C0Z250_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z250/C0Z250_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z250/C0Z250_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z270/C0Z270_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0Z270/C0Z270_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0
# C1U670 2019 downloaded
# C1U670 2021 downloaded
# Try downloading 590 C1U690 1996
# Try downloading 590 C1U690 1997
# Try downloading 590 C1U690 1998
# Try downloading 590 C1U690 1999
# Try downloading 590 C1U690 2000
# Try downloading 590 C1U690 2001
# Try downloading 590 C1U690 2002
# Try downloading 590 C1U690 2003
# Try downloading 590 C1U690 2004
# Try downloading 590 C1U690 2005
# Try downloading 590 C1U690 2006
# Try downloading 590 C1U690 2007
# Try downloading 590 C1U690 2008
# Try downloading 590 C1U690 2009
# Try downloading 590 C1U690 2010
# Try downloading 590 C1U690 2011
# Try downloading 590 C1U690 2012
# Try downloading 590 C1U690 2013
# Try downloading 590 C1U690 2014
# Try downloading 590 C1U690 2015
# Try downloading 590 C1U690 2016
# Try downloading 590 C1U690 2017
# Try downloading 590 C1U690 2018
# Try downloading 590 C1U690 2019
# Try downloading 590 C1U690 2020
# Try downloading 590 C1U690 2021
# Try downloading 590 C1U690 2022
# C1U690 1999 downloaded
# C1U690 2001 downloaded
# C1U690 2000 downloaded
# C1U690 2004 downloaded
# C1U690 2005 downloaded
# C1U690 1996 downloaded
# C1U690 1998 downloaded
# C1U690 2003 downloaded
# C1U690C1U690 1997 downloaded
#  2002 downloaded
# C1U690 2007 downloaded
# C1U690 2006 downloaded
# C1U690 2011 downloaded
# C1U690 2009 downloaded
# C1U690 2015 downloaded
# C1U690 2014 downloaded
# C1U690 2008 downloaded
# C1U690 2013 downloaded
# C1U690 2010 downloaded
# C1U690 2012 downloaded
# C1U690 2022 downloaded
# C1U690 2017 downloaded
# C1U690 2016 downloaded
# C1U690 2019 downloadedC1U690 2018
#  downloaded
# C1U690 2021 downloaded
# C1U690 2020 downloaded
# Try downloading 591 C1U840 2011
# Try downloading 591 C1U840 2012
# Try downloading 591 C1U840 2013
# Try downloading 591 C1U840 2014
# Try downloading 591 C1U840 2015
# Try downloading 591 C1U840 2016
# Try downloading 591 C1U840 2017
# Try downloading 591 C1U840 2018
# Try downloading 591 C1U840 2019
# Try downloading 591 C1U840 2020
# Try downloading 591 C1U840 2021
# Try downloading 591 C1U840 2022
# C1U840 2011 downloaded
# C1U840 2015 downloaded
# C1U840 2013 downloaded
# C1U840 2014 downloaded
# C1U840 2016 downloaded
# C1U840 2017 downloaded
# C1U840 2020 downloaded
# C1U840 2019 downloaded
# C1U840 2012 downloaded
# C1U840 2018 downloaded
# C1U840 2022 downloaded
# C1U840 2021 downloaded
# Try downloading 592 C1U850 2011
# Try downloading 592 C1U850 2012
# Try downloading 592 C1U850 2013
# Try downloading 592 C1U850 2014
# Try downloading 592 C1U850 2015
# Try downloading 592 C1U850 2016
# Try downloading 592 C1U850 2017
# Try downloading 592 C1U850 2018
# Try downloading 592 C1U850 2019
# Try downloading 592 C1U850 2020
# Try downloading 592 C1U850 2021
# Try downloading 592 C1U850 2022
# C1U850 2011 downloaded
# C1U850 2013 downloaded
# C1U850 2020 downloaded
# C1U850 2017 downloaded
# C1U850 2018 downloaded
# C1U850 2015 downloaded
# C1U850 2016 downloaded
# C1U850 2014 downloaded
# C1U850 2012 downloaded
# C1U850 2019 downloaded
