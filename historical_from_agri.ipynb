# %%
from google.colab import drive
drive.mount('/content/drive')
ROOT = './'
ROOT='/content/drive/MyDrive/Colab Notebooks/historical_weather'
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import requests
from dateutil.parser import parse
import json
from datetime import datetime, timedelta
import os

# %%
def agr_get_sta_list(area_id=0, level_id=0):
    my_headers = {    
        "accept": "application/json, text/javascript, */*; q=0.01",
        "accept-language": "ja-JP,ja;q=0.9,zh-TW;q=0.8,zh;q=0.7,en-US;q=0.6,en;q=0.5",
        "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
        "sec-ch-ua": "\"Chromium\";v=\"92\", \" Not A;Brand\";v=\"99\", \"Google Chrome\";v=\"92\"",
        "sec-ch-ua-mobile": "?0",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "x-requested-with": "XMLHttpRequest", #required
    }
    URI = 'https://agr.cwb.gov.tw/NAGR/history/station_day/get_station_name'
    area = ['', '北', '中', '南', '東'][area_id]
    level = ['自動站', '新農業站'][level_id]
    r1 = requests.post(URI, data={'area':area, 'level':level}, headers = my_headers)
    sta_dict = json.loads(r1.text)
    df = pd.DataFrame(sta_dict)
    extract_df = df[['ID', 'Cname', 'Altitude', 'Latitude_WGS84', 'Longitude_WGS84', 'Address', 'StnBeginTime', 'stnendtime', 'stationlist_auto']]
    extract_df.columns=['站號', '站名', '海拔高度(m)', '緯度', '經度', '地址', '資料起始日期', '撤站日期', '備註']
    return extract_df
def load_weather_station_list(include_suspended = False, include_agr_sta = True):
    #load from CWB
    raw = pd.read_html('https://e-service.cwb.gov.tw/wdps/obs/state.htm')
    weather_station_list = raw[0]
    if include_suspended:
        weather_station_list =  weather_station_list.append(raw[1])
    #load from agri
    if include_agr_sta:
        weather_station_list = weather_station_list.append(agr_get_sta_list(level_id=1), ignore_index = True)
    return weather_station_list

# %%
#Fetch From https://agr.cwb.gov.tw/NAGR/history/station_day
my_headers = {    
    "accept": "application/json, text/javascript, */*; q=0.01",
    "accept-language": "ja-JP,ja;q=0.9,zh-TW;q=0.8,zh;q=0.7,en-US;q=0.6,en;q=0.5",
    "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
    "sec-ch-ua": "\"Chromium\";v=\"92\", \" Not A;Brand\";v=\"99\", \"Google Chrome\";v=\"92\"",
    "sec-ch-ua-mobile": "?0",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "x-requested-with": "XMLHttpRequest", #required
}

def agr_get_hour_data (station = '466910', start_time = '2021-08-24', end_time = '2021-08-24', items=['PrecpHour']):
    get_hour = "https://agr.cwb.gov.tw/NAGR/history/station_hour/get_station_hour"
    #資料有可能存在「自動站」的資料庫
    #資料庫對自動站及農業站的日期處理行為不同
    start_time_dt = parse(start_time)
    end_time_dt = parse(end_time)
    r1 = requests.post(get_hour, data = {'station' : station, 'start_time': start_time_dt.strftime('%Y%m%d'), 'end_time': end_time_dt.strftime('%Y%m%d'), 'items[]': items, 'level': ''}, headers = my_headers)
    r2 = requests.post(get_hour, data = {'station' : station, 'start_time': start_time_dt.strftime('%Y%m%d'), 'end_time': end_time_dt.strftime('%Y%m%d'), 'items[]': items, 'level': '自動站'}, headers = my_headers)
    #return r1.text,r2.text
    #Try parsing return data
    try:
        r1_parsed = json.loads(r1.text)['result']
    except Exception as e:
        r1_parsed=[]
        print('r1 parse error: ',e, r1.text)
        
    try:
        r2_parsed = json.loads(r2.text)['result']
    except Exception as e:
        r2_parsed=[]
        print('r2 parse error: ',e, r2.text)

    
    #only one of r1 and r2 will contain required data
    if r1_parsed != []:
        #print (station, "為農業站")
        return r1_parsed
    if r2_parsed != []:
        #print (station, "為自動站")
        return r2_parsed
    return []


def agr_get_items (station = '466910'): #check available fields
    get_items_URI = "https://agr.cwb.gov.tw/NAGR/history/station_day/get_items"
    r = requests.post(get_items_URI, data = {'station': station},  headers= my_headers)
    try:
        return json.loads(r.text)['columns']
    except:
        return r.text
    
def agr_parsing (f):
    try:
        rt = list(f.values())[0]
        rt = float(rt)
        if rt < -90:
            return -999
        return rt
    except Exception as e:
        return -999
    
    
def agr_fetch (station_num=467080, date='2021-08-16'):
    output_columns = {
        'StaNO': '站號',
        'ObsTime': '觀測時間(hour)',
        'StnPres': '測站氣壓(hPa)',
        'SeaPres': '海平面氣壓(hPa)',
        'Tx': '氣溫(℃)',
        'Td': '露點溫度(℃)',
        'RH': '相對溼度(%)',
        'WS': '風速(m/s)',
        'WD': '風向(360degree)',
        'WSGust': '最大陣風(m/s)',
        'WDGust': '最大陣風風向(360degree)',
        'Precp': '降水量(mm)',
        'PrecpHr': '降水時數(hr)',
        'SunShine': '日照時數(hr)',
        'GloblRad': '全天空日射量(MJ/㎡)',
        'Visb': '能見度(km)',
        'UVI': '紫外線指數',
        'Cloud':'總雲量(0~10)'}
    #initialize the dataFrame
    station='C0Z200'
    df = pd.DataFrame(columns = output_columns.values())
    #如果items裡面放了他資料庫沒有的東西，會發生錯誤。所以得自己先確認交集
    sta_item = set(output_columns.keys()).intersection(agr_get_items(station_num))
    d = agr_get_hour_data(station=station_num,start_time=date, end_time=date, items=sta_item)
    df['觀測時間(hour)'] = pd.date_range(date+' 01:00:00', periods=24, freq='1h')
    df['站號'] = station_num
    df.set_index('觀測時間(hour)', inplace=True)
    #if no valid data
    if (d==[]):
        return pd.DataFrame()
    for single_factor in d:
        for rec in single_factor:
            #{'StnPres': '924.4', 'ObsTime': '2020-08-15 02:00:00'}
            ObsTime = parse(rec['ObsTime'])
            #in case of 8/16 23:59:00
            if ObsTime.strftime('%H%M')=='2359':
                ObsTime += timedelta(minutes=1)
            del rec['ObsTime']
            #After deleting ObsTime, the last key left is the observation data
            col_code = list(rec)[0]
            col_name = output_columns[col_code]
            #fill the data into the table
            df.loc[ObsTime,col_name] = rec[col_code]

    df.fillna(-999, inplace=True)
    df.reset_index(inplace=True)
    #dt need to be converted to str before enter MySQL
    df['觀測時間(hour)'] = df['觀測時間(hour)'].dt.strftime('%Y-%m-%d %H:%i:%s')
    
    return df

def agr_fetch_year_full (station_num=467080, year='2021', save_path = ''):
    sta_item = agr_get_items(station_num)
    df = pd.DataFrame()
    for month in range(1,13):
        start_time = '{}/{}/{}'.format(year,month,'1')
        if month == 12:
            end_time = '{}/{}/{}'.format(year,month,'31')
        else:
            end_time = (parse('{}/{}/{}'.format(year,month + 1,'1')) - timedelta(days = 1)).strftime('%Y/%m/%d')
        data_list = agr_get_hour_data(station=station_num,start_time=start_time, end_time=end_time, items=sta_item)
        df = df.append(agr_factor_to_df(data_list))     
    if save_path != '':
        df.to_csv(save_path, encoding = 'utf-8-sig')
    print(station_num, year,'downloaded')
    return df
    
def add_1min_to_2359 (d):
    if d.strftime('%H%M')=='2359':
        d += timedelta(minutes=1)
    return d

def agr_factor_to_df (d):
    df = pd.DataFrame()
    for r in d:
       
        keys = list(r[0])
        keys.remove('ObsTime')
        #There will be two keys in the data, one is the observation time, and the other is the query data
        factor_key = keys[0]
        data = [row[factor_key] for row in r]
        ObsTime = [parse(row['ObsTime']) for row in r]
        ObsTime = list(map(add_1min_to_2359 , ObsTime))
        df_temp = pd.DataFrame(index = ObsTime)
        #df_temp.index = ObsTime
        df_temp[factor_key] = data
        if df.empty:
            df = df_temp.copy()
        else: 
            df = pd.merge(df, df_temp, left_index=True, right_index=True, how='outer')
    return df

# %%
sta_list = load_weather_station_list(include_suspended = True)

# %%
import concurrent.futures

# %%
for index, row in sta_list[1:].iterrows():
    sta_info = {}
    sta_info ['sta_no'] = row[0]
    sta_info ['sta_name'] = row[1]
    sta_info ['start'] = parse(row[7])
    try:
        sta_info ['end'] = parse(row[8])
    except Exception as e:
        sta_info ['end'] = datetime.today()
    DIR_PATH = os.path.join(ROOT,'data',sta_info ['sta_no'])
    os.makedirs(DIR_PATH, exist_ok=True)
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures=[]
        for year in range(sta_info['start'].year, sta_info['end'].year +1):
            CSV_PATH = os.path.join(DIR_PATH,sta_info['sta_no']+'_'+str(year)+'.csv')
            try:
                #Check if file is already downloded
                if os.path.isfile(CSV_PATH) == False:
                    print ('Try downloading',index, sta_info['sta_no'], year)
                    future = executor.submit(
                                                agr_fetch_year_full, sta_info['sta_no'], 
                                                year, 
                                                CSV_PATH
                                            )
                    futures.append(future)
                else:
                    print(CSV_PATH, 'already downloaded, skipped')
            except Exception as e:
                print(e)
        #wait job to be finished
        try:
            for future in futures:
                future.result(timeout=300)
        except concurrent.futures.TimeoutError:
            print('Timeout error', future)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O830/C0O830_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O830/C0O830_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O830/C0O830_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O830/C0O830_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O830/C0O830_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O830/C0O830_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O830/C0O830_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O830/C0O830_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O840/C0O840_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O840/C0O840_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O840/C0O840_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O840/C0O840_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O840/C0O840_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O840/C0O840_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O840/C0O840_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O840/C0O840_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O840/C0O840_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O840/C0O840_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O860/C0O860_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O860/C0O860_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O860/C0O860_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O860/C0O860_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O860/C0O860_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O860/C0O860_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O860/C0O860_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O860/C0O860_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O860/C0O860_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O860/C0O860_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_1988.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_1989.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_1990.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_1991.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_1992.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_1993.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_1994.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_1995.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_1996.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_1997.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_1998.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_1999.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2000.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2001.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2002.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2003.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2004.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2005.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2006.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O900/C0O900_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_1988.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_1989.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_1990.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_1991.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_1992.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_1993.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_1994.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_1995.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_1996.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_1997.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_1998.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_1999.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2000.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2001.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2002.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2003.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2004.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2005.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2006.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O930/C0O930_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O950/C0O950_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O950/C0O950_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O950/C0O950_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O950/C0O950_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O950/C0O950_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O950/C0O950_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O950/C0O950_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O950/C0O950_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O950/C0O950_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O950/C0O950_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O960/C0O960_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O960/C0O960_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O960/C0O960_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O960/C0O960_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O960/C0O960_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O960/C0O960_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O960/C0O960_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O960/C0O960_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O960/C0O960_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O960/C0O960_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O970/C0O970_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O970/C0O970_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O970/C0O970_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O970/C0O970_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O970/C0O970_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O970/C0O970_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O970/C0O970_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O970/C0O970_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O970/C0O970_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O970/C0O970_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O980/C0O980_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O980/C0O980_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O980/C0O980_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O980/C0O980_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O980/C0O980_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O980/C0O980_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O980/C0O980_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O980/C0O980_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O980/C0O980_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O980/C0O980_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O990/C0O990_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O990/C0O990_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O990/C0O990_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O990/C0O990_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O990/C0O990_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O990/C0O990_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O990/C0O990_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O990/C0O990_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O990/C0O990_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0O990/C0O990_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_1992.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_1993.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_1994.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_1995.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_1996.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_1997.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_1998.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_1999.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2000.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2001.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2002.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2003.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2004.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2005.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2006.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R100/C0R100_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R130/C0R130_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R130/C0R130_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R130/C0R130_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R130/C0R130_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R130/C0R130_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R130/C0R130_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R130/C0R130_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R130/C0R130_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R130/C0R130_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R130/C0R130_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R140/C0R140_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R140/C0R140_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R140/C0R140_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R140/C0R140_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R140/C0R140_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R140/C0R140_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R140/C0R140_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R140/C0R140_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R140/C0R140_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R140/C0R140_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_1992.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_1993.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_1994.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_1995.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_1996.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_1997.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_1998.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_1999.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2000.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2001.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2002.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2003.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2004.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2005.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2006.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R150/C0R150_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R160/C0R160_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R160/C0R160_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R160/C0R160_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R160/C0R160_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R160/C0R160_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R160/C0R160_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R160/C0R160_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R160/C0R160_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R160/C0R160_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R160/C0R160_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R170/C0R170_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R170/C0R170_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R170/C0R170_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R170/C0R170_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R170/C0R170_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R170/C0R170_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R170/C0R170_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R170/C0R170_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R170/C0R170_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R170/C0R170_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R190/C0R190_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R190/C0R190_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R190/C0R190_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R190/C0R190_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R190/C0R190_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R190/C0R190_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R190/C0R190_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R190/C0R190_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R190/C0R190_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R190/C0R190_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_1992.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_1993.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_1994.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_1995.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_1996.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_1997.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_1998.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_1999.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2000.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2001.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2002.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2003.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2004.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2005.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2006.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R220/C0R220_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R240/C0R240_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R240/C0R240_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R240/C0R240_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R240/C0R240_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R240/C0R240_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R240/C0R240_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R240/C0R240_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R240/C0R240_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R240/C0R240_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R240/C0R240_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R260/C0R260_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R260/C0R260_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R260/C0R260_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R260/C0R260_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R260/C0R260_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R260/C0R260_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R260/C0R260_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R260/C0R260_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R260/C0R260_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R260/C0R260_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_1997.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_1998.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_1999.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2000.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2001.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2002.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2003.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2004.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2005.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2006.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R270/C0R270_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_1997.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_1998.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_1999.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2000.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2001.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2002.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2003.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2004.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2005.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2006.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R280/C0R280_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R320/C0R320_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R320/C0R320_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R320/C0R320_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R320/C0R320_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R341/C0R341_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R341/C0R341_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R341/C0R341_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R341/C0R341_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_1997.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_1998.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_1999.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2000.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2001.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2002.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2003.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2004.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2005.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2006.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2007.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2008.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2009.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2010.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2011.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2012.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R350/C0R350_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R440/C0R440_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R440/C0R440_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R440/C0R440_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R440/C0R440_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R470/C0R470_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R470/C0R470_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R470/C0R470_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R470/C0R470_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R470/C0R470_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R470/C0R470_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R470/C0R470_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R470/C0R470_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R470/C0R470_2021.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R470/C0R470_2022.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R480/C0R480_2013.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R480/C0R480_2014.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R480/C0R480_2015.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R480/C0R480_2016.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R480/C0R480_2017.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R480/C0R480_2018.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R480/C0R480_2019.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R480/C0R480_2020.csv already downloaded, skipped
# /content/drive/MyDrive/Colab Notebooks/historical_weather/data/C0R480/C0R480_2021.csv already downloaded, skipped
# ...
# C1I131 2015 downloaded
# C1I131 2022 downloaded
# C1I131 2021 downloaded
# Try downloading 525 C1I140 1993
# Try downloading 525 C1I140 1994
# Try downloading 525 C1I140 1995
# Try downloading 525 C1I140 1996
# Try downloading 525 C1I140 1997
# Try downloading 525 C1I140 1998
# Try downloading 525 C1I140 1999
# Try downloading 525 C1I140 2000
# Try downloading 525 C1I140 2001
# Try downloading 525 C1I140 2002
# Try downloading 525 C1I140 2003
# Try downloading 525 C1I140 2004
# Try downloading 525 C1I140 2005
# Try downloading 525 C1I140 2006
# Try downloading 525 C1I140 2007
# Try downloading 525 C1I140 2008
# Try downloading 525 C1I140 2009
# Try downloading 525 C1I140 2010
# Try downloading 525 C1I140 2011
# Try downloading 525 C1I140 2012
# Try downloading 525 C1I140 2013
# Try downloading 525 C1I140 2014
# Try downloading 525 C1I140 2015
# Try downloading 525 C1I140 2016
# Try downloading 525 C1I140 2017
# Try downloading 525 C1I140 2018
# Try downloading 525 C1I140 2019
# Try downloading 525 C1I140 2020
# Try downloading 525 C1I140 2021
# Try downloading 525 C1I140 2022
# C1I140 1996 downloaded
# C1I140 1995 downloaded
# C1I140 1993 downloaded
# C1I140 1999 downloaded
# C1I140 2001 downloaded
# C1I140 1994 downloaded
# C1I140 2000 downloaded
# C1I140 2002 downloaded
# C1I140 1997 downloaded
# C1I140 1998 downloaded
# C1I140 2003 downloaded
# C1I140 2004 downloaded
# C1I140 2005 downloaded
# C1I140 2007 downloaded
# C1I140 2008 downloaded
# C1I140 2009 downloaded
# C1I140 2011 downloaded
# C1I140 2006 downloaded
# C1I140 2010 downloaded
# C1I140 2012 downloaded
# C1I140 2013 downloaded
# C1I140 2015 downloaded
# C1I140 2022 downloaded
# C1I140 2014 downloaded
# C1I140 2019 downloaded
# C1I140 2017 downloaded
# C1I140 2016 downloaded
# C1I140 2018 downloaded
# C1I140 2020 downloaded
# C1I140 2021 downloaded
# Try downloading 526 C1I150 1993
# Try downloading 526 C1I150 1994
# Try downloading 526 C1I150 1995
# Try downloading 526 C1I150 1996
# Try downloading 526 C1I150 1997
# Try downloading 526 C1I150 1998
# Try downloading 526 C1I150 1999
# Try downloading 526 C1I150 2000
# Try downloading 526 C1I150 2001
# Try downloading 526 C1I150 2002
# Try downloading 526 C1I150 2003
# Try downloading 526 C1I150 2004
# Try downloading 526 C1I150 2005
# Try downloading 526 C1I150 2006
# Try downloading 526 C1I150 2007
# Try downloading 526 C1I150 2008
# Try downloading 526 C1I150 2009
# Try downloading 526 C1I150 2010
# Try downloading 526 C1I150 2011
# Try downloading 526 C1I150 2012
# Try downloading 526 C1I150 2013
# Try downloading 526 C1I150 2014
# Try downloading 526 C1I150 2015
# Try downloading 526 C1I150 2016
# Try downloading 526 C1I150 2017
# Try downloading 526 C1I150 2018
# Try downloading 526 C1I150 2019
# Try downloading 526 C1I150 2020
# Try downloading 526 C1I150 2021
# Try downloading 526 C1I150 2022
# C1I150 2000 downloaded
# C1I150 1993 downloaded
# C1I150 1995 downloaded
# C1I150 1994 downloaded
# C1I150 2001 downloaded
# C1I150 1998 downloaded
# C1I150 1997 downloaded
# C1I150 2002 downloaded
# C1I150 1999 downloaded
# C1I150 1996 downloaded
# C1I150 2005 downloaded
# C1I150 2003 downloaded
# C1I150 2004 downloaded
# C1I150 2008 downloaded
# C1I150 2007 downloaded
# C1I150 2012 downloaded
# C1I150 2010 downloaded
# C1I150 2009 downloaded
# C1I150 2011 downloaded
# C1I150 2006 downloaded
# C1I150 2015 downloaded
# C1I150 2022 downloaded
# C1I150 2016 downloaded
# C1I150 2013 downloaded
# C1I150 2014 downloaded
# C1I150 2017 downloaded
# C1I150 2018 downloaded
# C1I150 2020 downloaded
# C1I150 2019 downloaded
# C1I150 2021 downloaded
# Try downloading 527 C1I201 2011
# Try downloading 527 C1I201 2012
# Try downloading 527 C1I201 2013
# Try downloading 527 C1I201 2014
# Try downloading 527 C1I201 2015
# Try downloading 527 C1I201 2016
# Try downloading 527 C1I201 2017
# Try downloading 527 C1I201 2018
# Try downloading 527 C1I201 2019
# Try downloading 527 C1I201 2020
# Try downloading 527 C1I201 2021
# Try downloading 527 C1I201 2022
# C1I201 2011 downloaded
# C1I201 2012 downloaded
# C1I201 2019 downloaded
# C1I201 2018 downloaded
# C1I201 2013 downloaded
# C1I201 2020 downloaded
# C1I201 2014 downloaded
# C1I201 2016 downloaded
# C1I201 2015 downloaded
# C1I201 2017 downloaded
# C1I201 2021 downloaded
# C1I201 2022 downloaded
# Try downloading 528 C1I211 2011
# Try downloading 528 C1I211 2012
# Try downloading 528 C1I211 2013
# Try downloading 528 C1I211 2014
# Try downloading 528 C1I211 2015
# Try downloading 528 C1I211 2016
# Try downloading 528 C1I211 2017
# Try downloading 528 C1I211 2018
# Try downloading 528 C1I211 2019
# Try downloading 528 C1I211 2020
# Try downloading 528 C1I211 2021
# Try downloading 528 C1I211 2022
# C1I211 2011 downloaded
# C1I211 2015 downloaded
# C1I211 2019 downloaded
# C1I211 2014 downloaded
# C1I211 2020 downloaded
# C1I211 2012 downloaded
# C1I211 2016 downloaded
# C1I211 2018 downloaded
# C1I211 2017 downloaded
# C1I211 2013 downloaded
# C1I211 2022 downloaded
# C1I211 2021 downloaded
# Try downloading 529 C1I220 2002
# Try downloading 529 C1I220 2003
# Try downloading 529 C1I220 2004
# Try downloading 529 C1I220 2005
# Try downloading 529 C1I220 2006
# Try downloading 529 C1I220 2007
# Try downloading 529 C1I220 2008
# Try downloading 529 C1I220 2009
# Try downloading 529 C1I220 2010
# Try downloading 529 C1I220 2011
# Try downloading 529 C1I220 2012
# Try downloading 529 C1I220 2013
# Try downloading 529 C1I220 2014
# Try downloading 529 C1I220 2015
# Try downloading 529 C1I220 2016
# Try downloading 529 C1I220 2017
# Try downloading 529 C1I220 2018
# Try downloading 529 C1I220 2019
# Try downloading 529 C1I220 2020
# Try downloading 529 C1I220 2021
# Try downloading 529 C1I220 2022
# C1I220 2002 downloaded
# C1I220 2005 downloaded
# C1I220 2010 downloaded
# C1I220 2007 downloaded
# C1I220 2008 downloaded
# C1I220 2006 downloaded
# C1I220 2004 downloaded
# C1I220 2009 downloaded
# C1I220 2003 downloaded
# C1I220 2011 downloaded
# C1I220 2015 downloaded
# C1I220 2012 downloaded
# C1I220 2013 downloaded
# C1I220 2014 downloaded
# C1I220C1I220 2017 downloaded
#  2016 downloaded
# C1I220 2020 downloaded
# C1I220 2018 downloaded
# C1I220 2019 downloaded
# C1I220 2021 downloaded
# C1I220 2022 downloaded
# Try downloading 530 C1I230 2002
# Try downloading 530 C1I230 2003
# Try downloading 530 C1I230 2004
# Try downloading 530 C1I230 2005
# Try downloading 530 C1I230 2006
# Try downloading 530 C1I230 2007
# Try downloading 530 C1I230 2008
# Try downloading 530 C1I230 2009
# Try downloading 530 C1I230 2010
# Try downloading 530 C1I230 2011
# Try downloading 530 C1I230 2012
# Try downloading 530 C1I230 2013
# Try downloading 530 C1I230 2014
# Try downloading 530 C1I230 2015
# Try downloading 530 C1I230 2016
# Try downloading 530 C1I230 2017
# Try downloading 530 C1I230 2018
# Try downloading 530 C1I230 2019
# Try downloading 530 C1I230 2020
# Try downloading 530 C1I230 2021
# Try downloading 530 C1I230 2022
# C1I230 2002 downloaded
# C1I230 2008 downloaded
# C1I230 2004 downloaded
# C1I230 2009 downloaded
# C1I230 2007 downloaded
# C1I230 2011 downloaded
# C1I230C1I230 2006 downloaded
#  2010 downloaded
# C1I230 2005 downloaded
# C1I230 2003 downloaded
# C1I230 2015 downloaded
# C1I230 2012 downloaded
# C1I230 2013 downloaded
# C1I230 2014 downloaded
# C1I230 2016 downloaded
# C1I230 2017 downloaded
# C1I230 2018 downloaded
# C1I230 2021 downloaded
# C1I230 2019 downloaded
# C1I230 2020 downloaded
# C1I230 2022 downloaded
# Try downloading 531 C1I240 2002
# Try downloading 531 C1I240 2003
# Try downloading 531 C1I240 2004
# Try downloading 531 C1I240 2005
# Try downloading 531 C1I240 2006
# Try downloading 531 C1I240 2007
# Try downloading 531 C1I240 2008
# Try downloading 531 C1I240 2009
# Try downloading 531 C1I240 2010
# Try downloading 531 C1I240 2011
# Try downloading 531 C1I240 2012
# Try downloading 531 C1I240 2013
# Try downloading 531 C1I240 2014
# Try downloading 531 C1I240 2015
# Try downloading 531 C1I240 2016
# Try downloading 531 C1I240 2017
# Try downloading 531 C1I240 2018
# Try downloading 531 C1I240 2019
# Try downloading 531 C1I240 2020
# Try downloading 531 C1I240 2021
# Try downloading 531 C1I240 2022
# C1I240 2009 downloaded
# C1I240 2002 downloaded
# C1I240 2011 downloaded
# C1I240 2005 downloaded
# C1I240 2008 downloaded
# C1I240 2003 downloaded
# C1I240 2004 downloaded
# C1I240 2007C1I240 2006 downloaded
#  downloaded
# C1I240 2010 downloaded
# C1I240 2015 downloaded
# C1I240 2017 downloaded
# C1I240 2016 downloaded
# C1I240C1I240 2014 downloaded
#  2013 downloaded
# C1I240 2020 downloaded
# C1I240 2012 downloaded
# C1I240 2019 downloaded
# C1I240 2018 downloaded
# C1I240 2021 downloaded
# C1I240 2022 downloaded
# Try downloading 532 C1I250 2002
# Try downloading 532 C1I250 2003
# Try downloading 532 C1I250 2004
# Try downloading 532 C1I250 2005
# Try downloading 532 C1I250 2006
# Try downloading 532 C1I250 2007
# Try downloading 532 C1I250 2008
# Try downloading 532 C1I250 2009
# Try downloading 532 C1I250 2010
# Try downloading 532 C1I250 2011
# Try downloading 532 C1I250 2012
# Try downloading 532 C1I250 2013
# Try downloading 532 C1I250 2014
# Try downloading 532 C1I250 2015
# Try downloading 532 C1I250 2016
# Try downloading 532 C1I250 2017
# Try downloading 532 C1I250 2018
# Try downloading 532 C1I250 2019
# Try downloading 532 C1I250 2020
# Try downloading 532 C1I250 2021
# Try downloading 532 C1I250 2022
# C1I250 2005 downloaded
# C1I250 2003 downloaded
# C1I250 2002 downloaded
# C1I250 2004 downloaded
# C1I250 2011 downloaded
# C1I250 2009 downloaded
# C1I250 2008 downloaded
# C1I250 2006 downloaded
# C1I250 2007 downloaded
# C1I250 2010 downloaded
# C1I250 2012 downloaded
# C1I250 2017 downloaded
# C1I250 2015 downloaded
# C1I250 2016 downloaded
# C1I250 2018 downloaded
# C1I250 2019 downloaded
# C1I250 2020 downloaded
# C1I250 2014 downloaded
# C1I250 2013 downloaded
# C1I250 2021 downloaded
# C1I250 2022 downloaded
# Try downloading 533 C1I260 2002
# Try downloading 533 C1I260 2003
# Try downloading 533 C1I260 2004
# Try downloading 533 C1I260 2005
# Try downloading 533 C1I260 2006
# Try downloading 533 C1I260 2007
# Try downloading 533 C1I260 2008
# Try downloading 533 C1I260 2009
# Try downloading 533 C1I260 2010
# Try downloading 533 C1I260 2011
# Try downloading 533 C1I260 2012
# Try downloading 533 C1I260 2013
# Try downloading 533 C1I260 2014
# Try downloading 533 C1I260 2015
# Try downloading 533 C1I260 2016
# Try downloading 533 C1I260 2017
# Try downloading 533 C1I260 2018
# Try downloading 533 C1I260 2019
# Try downloading 533 C1I260 2020
# Try downloading 533 C1I260 2021
# Try downloading 533 C1I260 2022
# C1I260 2002 downloaded
# C1I260 2011 downloaded
# C1I260 2009 downloaded
# C1I260 2008 downloaded
# C1I260 2003 downloaded
# C1I260 2007 downloaded
# C1I260 2005 downloaded
# C1I260 2010 downloaded
# C1I260 2006 downloaded
# C1I260 2004 downloaded
# C1I260 2015 downloaded
# C1I260 2013 downloaded
# C1I260 2014 downloaded
# C1I260 2012 downloaded
# C1I260 2017 downloaded
# C1I260 2018 downloaded
# C1I260 2021 downloaded
# C1I260 2019 downloaded
# C1I260 2020 downloaded
# C1I260 2016 downloaded
# C1I260 2022 downloaded
# Try downloading 534 C1I280 2002
# Try downloading 534 C1I280 2003
# Try downloading 534 C1I280 2004
# Try downloading 534 C1I280 2005
# Try downloading 534 C1I280 2006
# Try downloading 534 C1I280 2007
# Try downloading 534 C1I280 2008
# Try downloading 534 C1I280 2009
# Try downloading 534 C1I280 2010
# Try downloading 534 C1I280 2011
# Try downloading 534 C1I280 2012
# Try downloading 534 C1I280 2013
# Try downloading 534 C1I280 2014
# Try downloading 534 C1I280 2015
# Try downloading 534 C1I280 2016
# Try downloading 534 C1I280 2017
# Try downloading 534 C1I280 2018
# Try downloading 534 C1I280 2019
# Try downloading 534 C1I280 2020
# Try downloading 534 C1I280 2021
# Try downloading 534 C1I280 2022
# C1I280 2002 downloaded
# C1I280 2004 downloaded
# C1I280 2009 downloaded
# C1I280 2011 downloaded
# C1I280 2006 downloaded
# C1I280 2005 downloaded
# C1I280 2007 downloaded
# C1I280 2003 downloaded
# C1I280 2010 downloaded
# C1I280 2008 downloaded
# C1I280 2015 downloaded
# C1I280 2012 downloaded
# C1I280 2013 downloaded
# C1I280 2016 downloaded
# C1I280 2017 downloaded
# C1I280 2014 downloaded
# C1I280 2018 downloaded
# C1I280 2021 downloaded
# C1I280 2019 downloaded
# C1I280 2020 downloaded
# C1I280 2022 downloaded
# Try downloading 535 C1I290 2002
# Try downloading 535 C1I290 2003
# Try downloading 535 C1I290 2004
# Try downloading 535 C1I290 2005
# Try downloading 535 C1I290 2006
# Try downloading 535 C1I290 2007
# Try downloading 535 C1I290 2008
# Try downloading 535 C1I290 2009
# Try downloading 535 C1I290 2010
# Try downloading 535 C1I290 2011
# Try downloading 535 C1I290 2012
# Try downloading 535 C1I290 2013
# Try downloading 535 C1I290 2014
# Try downloading 535 C1I290 2015
# Try downloading 535 C1I290 2016
# Try downloading 535 C1I290 2017
# Try downloading 535 C1I290 2018
# Try downloading 535 C1I290 2019
# Try downloading 535 C1I290 2020
# Try downloading 535 C1I290 2021
# Try downloading 535 C1I290 2022
# C1I290 2005 downloaded
# C1I290 2010 downloaded
# C1I290 2003 downloaded
# C1I290 2006 downloaded
# C1I290 2007 downloaded
# C1I290 2002 downloaded
# C1I290 2011 downloaded
# C1I290 2009 downloaded
# C1I290 2008 downloaded
# C1I290 2004 downloaded
# C1I290 2015 downloaded
# C1I290 2013 downloaded
# C1I290 2014 downloaded
# C1I290 2012 downloaded
# C1I290 2018 downloaded
# C1I290 2019 C1I290 2016 downloaded
# downloaded
# C1I290 2020 downloaded
# C1I290 2017 downloaded
# C1I290 2021 downloaded
# C1I290 2022 downloaded
# Try downloading 536 C1I310 2002
# Try downloading 536 C1I310 2003
# Try downloading 536 C1I310 2004
# Try downloading 536 C1I310 2005
# Try downloading 536 C1I310 2006
# Try downloading 536 C1I310 2007
# Try downloading 536 C1I310 2008
# Try downloading 536 C1I310 2009
# Try downloading 536 C1I310 2010
# Try downloading 536 C1I310 2011
# Try downloading 536 C1I310 2012
# Try downloading 536 C1I310 2013
# Try downloading 536 C1I310 2014
# Try downloading 536 C1I310 2015
# Try downloading 536 C1I310 2016
# Try downloading 536 C1I310 2017
# Try downloading 536 C1I310 2018
# Try downloading 536 C1I310 2019
# Try downloading 536 C1I310 2020
# Try downloading 536 C1I310 2021
# Try downloading 536 C1I310 2022
# C1I310 2010 downloaded
# C1I310 C1I310 2002 downloaded
# 2006 downloaded
# C1I310 2009 downloaded
# C1I310 2005 downloaded
# C1I310 2008 downloaded
# C1I310 2004 downloaded
# C1I310 2007 downloaded
# C1I310 2003 downloaded
# C1I310 2011 downloaded
# C1I310 2012 downloaded
# C1I310 2016 downloaded
# C1I310 2015 downloaded
# C1I310C1I310 2019 downloaded
#  2017 downloaded
# C1I310 2013 downloaded
# C1I310 2018 downloaded
# C1I310 2014 downloaded
# C1I310 2020 downloaded
# C1I310 2021 downloaded
# C1I310 2022 downloaded
# Try downloading 537 C1I320 2002
# Try downloading 537 C1I320 2003
# Try downloading 537 C1I320 2004
# Try downloading 537 C1I320 2005
# Try downloading 537 C1I320 2006
# Try downloading 537 C1I320 2007
# Try downloading 537 C1I320 2008
# Try downloading 537 C1I320 2009
# Try downloading 537 C1I320 2010
# Try downloading 537 C1I320 2011
# Try downloading 537 C1I320 2012
# Try downloading 537 C1I320 2013
# Try downloading 537 C1I320 2014
# Try downloading 537 C1I320 2015
# Try downloading 537 C1I320 2016
# Try downloading 537 C1I320 2017
# Try downloading 537 C1I320 2018
# Try downloading 537 C1I320 2019
# Try downloading 537 C1I320 2020
# Try downloading 537 C1I320 2021
# Try downloading 537 C1I320 2022
# C1I320 2002 downloaded
# C1I320 2009 downloaded
# C1I320 2008 downloaded
# C1I320 2006 downloaded
# C1I320 2007 downloaded
# C1I320 2011 downloaded
# C1I320 2010 downloaded
# C1I320 2005 downloaded
# C1I320 2004 downloaded
# C1I320 2003 downloaded
# C1I320 2015 downloaded
# C1I320 2013 downloaded
# C1I320 2014 downloaded
# C1I320 2016 downloaded
# C1I320 2020 downloaded
# C1I320 2017 downloaded
# C1I320 2019 downloaded
# C1I320 2012 downloaded
# C1I320 2021 downloaded
# C1I320 2018 downloaded
# C1I320 2022 downloaded
# Try downloading 538 C1I330 2002
# Try downloading 538 C1I330 2003
# Try downloading 538 C1I330 2004
# Try downloading 538 C1I330 2005
# Try downloading 538 C1I330 2006
# Try downloading 538 C1I330 2007
# Try downloading 538 C1I330 2008
# Try downloading 538 C1I330 2009
# Try downloading 538 C1I330 2010
# Try downloading 538 C1I330 2011
# Try downloading 538 C1I330 2012
# Try downloading 538 C1I330 2013
# Try downloading 538 C1I330 2014
# Try downloading 538 C1I330 2015
# Try downloading 538 C1I330 2016
# Try downloading 538 C1I330 2017
# Try downloading 538 C1I330 2018
# Try downloading 538 C1I330 2019
# Try downloading 538 C1I330 2020
# Try downloading 538 C1I330 2021
# Try downloading 538 C1I330 2022
# C1I330 2011 downloaded
# C1I330 2007 downloaded
# C1I330 2008 downloaded
# C1I330 2005 downloaded
# C1I330 2003 downloaded
# C1I330 2010 downloaded
# C1I330 2009 downloaded
# C1I330 2006 downloaded
# C1I330 2002 downloaded
# C1I330 2004 downloaded
